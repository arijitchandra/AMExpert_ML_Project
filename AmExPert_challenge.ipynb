# %% [markdown]
# ### Importing DataSets

# %%
import numpy as np # linear algebra
import pandas as pd # data processing

train = pd.read_csv('/Users/arijitchandra/Downloads/train_AmEx/train.csv')
cmpng = pd.read_csv('/Users/arijitchandra/Downloads/train_AmEx/campaign_data.csv')
item = pd.read_csv('/Users/arijitchandra/Downloads/train_AmEx/item_data.csv')
customer_dmogrph = pd.read_csv('/Users/arijitchandra/Downloads/train_AmEx/customer_demographics.csv')
coupon_item = pd.read_csv('/Users/arijitchandra/Downloads/train_AmEx/coupon_item_mapping.csv')
customer_tran = pd.read_csv('/Users/arijitchandra/Downloads/train_AmEx/customer_transaction_data.csv')
test = pd.read_csv('/Users/arijitchandra/Downloads/Test_AmEx/test_AmEx.csv')
sub = pd.read_csv('/Users/arijitchandra/Downloads/sample_sub_AmEx.csv')

# %% [markdown]
# ### Shape of DataSets

# %%
train.shape,cmpng.shape,item.shape,customer_dmogrph.shape,coupon_item.shape,customer_tran.shape
# Out:
# ((78369, 5), (28, 4), (74066, 4), (760, 7), (92663, 2), (1324566, 7))

# %%
test.shape,sub.shape
# Out:
# ((50226, 4), (50226, 2))

# %% [markdown]
# ### Finding DataSets with NaN values

# %%
print("Total Features with NaN Values in train = " + str(train.columns[train.isnull().sum() != 0].size))
print("Total Features with NaN Values in Campaign = " + str(cmpng.columns[cmpng.isnull().sum() != 0].size))
print("Total Features with NaN Values in item = " + str(item.columns[item.isnull().sum() != 0].size))
print("Total Features with NaN Values in Customer demography = " + str(customer_dmogrph.columns[customer_dmogrph.isnull().sum() != 0].size))
print("Total Features with NaN Values in coupon item relation = " + str(coupon_item.columns[coupon_item.isnull().sum() != 0].size))
print("Total Features with NaN Values in customer transaction = " + str(customer_tran.columns[customer_tran.isnull().sum() != 0].size))
print("Total Features with NaN Values in test = " + str(test.columns[test.isnull().sum() != 0].size))
print("Total Features with NaN Values in Sample sub = " + str(sub.columns[sub.isnull().sum() != 0].size))
# Out:
# Total Features with NaN Values in train = 0
# Total Features with NaN Values in Campaign = 0
# Total Features with NaN Values in item = 0
# Total Features with NaN Values in Customer demography = 2
# Total Features with NaN Values in coupon item relation = 0
# Total Features with NaN Values in customer transaction = 0
# Total Features with NaN Values in test = 0
# Total Features with NaN Values in Sample sub = 0

# %% [markdown]
# ### Columns with NaN value

# %%
customer_dmogrph.columns[customer_dmogrph.isna().any()].to_list()
# Out:
# ['marital_status', 'no_of_children']

# %% [markdown]
# ### Number of rows with NaN value

# %%
len(customer_dmogrph)-customer_dmogrph.count()
# Out:
# customer_id         0
# age_range           0
# marital_status    329
# rented              0
# family_size         0
# no_of_children    538
# income_bracket      0
# dtype: int64

# %% [markdown]
# ### Percentage of NaN values in each column

# %%
customer_dmogrph.isna().mean().round(4) * 100
# Out:
# customer_id        0.00
# age_range          0.00
# marital_status    43.29
# rented             0.00
# family_size        0.00
# no_of_children    70.79
# income_bracket     0.00
# dtype: float64

# %% [markdown]
# Close look at Customer demograghic dataset

# %%
customer_dmogrph.dtypes
# Out:
# customer_id        int64
# age_range         object
# marital_status    object
# rented             int64
# family_size       object
# no_of_children    object
# income_bracket     int64
# dtype: object

# %%
customer_dmogrph.head(20)
# Out:
#     customer_id age_range marital_status  rented family_size no_of_children  \
# 0             1       70+        Married       0           2            NaN
# 1             6     46-55        Married       0           2            NaN
# 2             7     26-35            NaN       0           3              1
# 3             8     26-35            NaN       0           4              2
# 4            10     46-55         Single       0           1            NaN
# 5            11       70+         Single       0           2            NaN
# 6            12     46-55        Married       0           2            NaN
# 7            13     36-45         Single       0           1            NaN
# 8            14     26-35        Married       1           2            NaN
# 9            15     46-55        Married       0           2            NaN
# 10           17     36-45            NaN       0           1            NaN
# 11           19     46-55            NaN       0           1            NaN
# 12           22     36-45         Single       0           2            NaN
# 13           27     36-45        Married       0           2            NaN
# 14           28     46-55            NaN       0           2            NaN
# 15           30       70+            NaN       0           1            NaN
# 16           31     36-45         Single       0          5+             3+
# 17           33     46-55        Married       0          5+             3+
# 18           35     18-25            NaN       0           2            NaN
# 19           36     36-45        Married       0           2            NaN
#
#     income_bracket
# 0                4
# 1                5
# 2                3
# 3                6
# 4                5
# 5                1
# 6                7
# 7                2
# 8                6
# 9                6
# 10               5
# 11               3
# 12               4
# 13               8
# 14               1
# 15               5
# 16               2
# 17               9
# 18               4
# 19               4

# %% [markdown]
# ### Converting age_range feature to some meaningful data...

# %%
import re
customer_dmogrph['age_min']=[re.split('\W',customer_dmogrph.age_range[i])[0] for i in range(len(customer_dmogrph))]
customer_dmogrph['age_max']=[re.split('\W',customer_dmogrph.age_range[i])[1] for i in range(len(customer_dmogrph))]
customer_dmogrph['age_max'].replace('',customer_dmogrph.age_min, inplace=True)

# %%
customer_dmogrph['age_max']=customer_dmogrph['age_max'].astype(int)
customer_dmogrph['age_min']=customer_dmogrph['age_min'].astype(int)
customer_dmogrph['age_avg']=[(customer_dmogrph.age_max[i]+customer_dmogrph.age_min[i])/2 
                             for i in range(len(customer_dmogrph))]

# %%
customer_dmogrph.drop('age_range', axis=1, inplace=True)
customer_dmogrph.dtypes
# Out:
# customer_id         int64
# marital_status     object
# rented              int64
# family_size        object
# no_of_children     object
# income_bracket      int64
# age_min             int64
# age_max             int64
# age_avg           float64
# dtype: object

# %% [markdown]
# ### Replacing NaN with 0 and then converting it to integer value for performing feature engineering

# %%
customer_dmogrph['no_of_children'].fillna(0, inplace=True)

# %%
customer_dmogrph['no_of_children'].replace('3+','3',inplace=True)

# %%
customer_dmogrph['family_size'].replace('5+', 5,inplace=True)

# %%
customer_dmogrph['marital_status']=customer_dmogrph['family_size'].astype(int)-customer_dmogrph['no_of_children'].astype(int)

# %% [markdown]
# ### Checking NaN values in operated DataSet

# %%
print("Total Features with NaN Values in train = " + str(train.columns[train.isnull().sum() != 0].size))
print("Total Features with NaN Values in Campaign = " + str(cmpng.columns[cmpng.isnull().sum() != 0].size))
print("Total Features with NaN Values in item = " + str(item.columns[item.isnull().sum() != 0].size))
print("Total Features with NaN Values in Customer demography = " + str(customer_dmogrph.columns[customer_dmogrph.isnull().sum() != 0].size))
print("Total Features with NaN Values in coupon item relation = " + str(coupon_item.columns[coupon_item.isnull().sum() != 0].size))
print("Total Features with NaN Values in customer transaction = " + str(customer_tran.columns[customer_tran.isnull().sum() != 0].size))
print("Total Features with NaN Values in test = " + str(test.columns[test.isnull().sum() != 0].size))
print("Total Features with NaN Values in Sample sub = " + str(sub.columns[sub.isnull().sum() != 0].size))
# Out:
# Total Features with NaN Values in train = 0
# Total Features with NaN Values in Campaign = 0
# Total Features with NaN Values in item = 0
# Total Features with NaN Values in Customer demography = 0
# Total Features with NaN Values in coupon item relation = 0
# Total Features with NaN Values in customer transaction = 0
# Total Features with NaN Values in test = 0
# Total Features with NaN Values in Sample sub = 0

# %% [markdown]
# ### Close look at the DataSet Description

# %%
train.describe()### Since mean is almost equals to median so no distribution seems to be normal. 
                ### and no modification is required
# Out:
#                   id   campaign_id     coupon_id   customer_id  \
# count   78369.000000  78369.000000  78369.000000  78369.000000
# mean    64347.975449     13.974441    566.363243    787.451888
# std     37126.440855      8.019215    329.966054    456.811339
# min         1.000000      1.000000      1.000000      1.000000
# 25%     32260.000000      8.000000    280.000000    399.000000
# 50%     64318.000000     13.000000    597.000000    781.000000
# 75%     96577.000000     13.000000    857.000000   1190.000000
# max    128595.000000     30.000000   1115.000000   1582.000000
#
#        redemption_status
# count       78369.000000
# mean            0.009302
# std             0.095999
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             0.000000
# max             1.000000

# %%
cmpng.describe()### Since mean is almost equals to median so no distribution seems to be normal. 
                ### and no modification is required
# Out:
#        campaign_id
# count    28.000000
# mean     15.571429
# std       9.118271
# min       1.000000
# 25%       7.750000
# 50%      16.500000
# 75%      23.250000
# max      30.000000

# %%
item.describe()### Brand value needs to be checked in deapth as there is deviation between mean and mode
# Out:
#             item_id         brand
# count  74066.000000  74066.000000
# mean   37033.500000   1485.560055
# std    21381.156856   1537.385673
# min        1.000000      1.000000
# 25%    18517.250000    278.000000
# 50%    37033.500000    978.000000
# 75%    55549.750000   2013.000000
# max    74066.000000   5528.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pylab as pl
item.hist(bins=30, figsize=(15,9),layout=(1,2))
pl.suptitle("Histogram for each numeric input variable for item dataset")
plt.show()

# %%
sns.kdeplot(np.tan(item.brand)) ### Non-linear transformation
plt.show()

# %%
np.tan(item.brand).isna().sum()
# Out:
# 0

# %%
#item.brand=np.tan(item.brand)

# %%
train.campaign_id.nunique(),cmpng.campaign_id.nunique()
# Out:
# (18, 28)

# %%
train.head()
# Out:
#    id  campaign_id  coupon_id  customer_id  redemption_status
# 0   1           13         27         1053                  0
# 1   2           13        116           48                  0
# 2   6            9        635          205                  0
# 3   7           13        644         1050                  0
# 4   9            8       1017         1489                  0

# %%
cmpng.head(50)
# Out:
#     campaign_id campaign_type start_date  end_date
# 0            24             Y   21/10/13  20/12/13
# 1            25             Y   21/10/13  22/11/13
# 2            20             Y   07/09/13  16/11/13
# 3            23             Y   08/10/13  15/11/13
# 4            21             Y   16/09/13  18/10/13
# 5            22             X   16/09/13  18/10/13
# 6            18             X   10/08/13  04/10/13
# 7            19             Y   26/08/13  27/09/13
# 8            17             Y   29/07/13  30/08/13
# 9            16             Y   15/07/13  16/08/13
# 10           13             X   19/05/13  05/07/13
# 11           11             Y   22/04/13  07/06/13
# 12           12             Y   22/04/13  24/05/13
# 13           10             Y   08/04/13  10/05/13
# 14            9             Y   11/03/13  12/04/13
# 15            8             X   16/02/13  05/04/13
# 16            7             Y   02/02/13  08/03/13
# 17            6             Y   28/01/13  01/03/13
# 18            3             Y   22/12/12  16/02/13
# 19            5             Y   12/01/13  15/02/13
# 20            4             Y   07/01/13  08/02/13
# 21            1             Y   12/12/12  18/01/13
# 22            2             Y   17/12/12  18/01/13
# 23           30             X   19/11/12  04/01/13
# 24           29             Y   08/10/12  30/11/12
# 25           28             Y   16/09/12  16/11/12
# 26           27             Y   25/08/12  27/10/12
# 27           26             X   12/08/12  21/09/12

# %% [markdown]
# ### Merging Train dataset with Campaign details

# %%
train = pd.merge(train, cmpng, on='campaign_id', how='left')
test = pd.merge(test, cmpng, on='campaign_id', how='left')
train.shape,test.shape
# Out:
# ((78369, 8), (50226, 7))

# %% [markdown]
# ### Merging customer transaction details with customer demographic details

# %%
cust_tran_demograph = pd.merge(customer_tran,customer_dmogrph, on='customer_id', how='left')
cust_tran_demograph.shape
# Out:
# (1324566, 15)

# %%
cust_tran_demograph.isna().mean().round(4) *100 ### Checking percentage of NaN values in merged dataset
# Out:
# date                0.00
# customer_id         0.00
# item_id             0.00
# quantity            0.00
# selling_price       0.00
# other_discount      0.00
# coupon_discount     0.00
# marital_status     40.24
# rented             40.24
# family_size        40.24
# no_of_children     40.24
# income_bracket     40.24
# age_min            40.24
# age_max            40.24
# age_avg            40.24
# dtype: float64

# %% [markdown]
# ### Combining item details with coupon details

# %%
coupon_item = pd.merge(coupon_item,item, on = 'item_id', how = 'left')
coupon_item.shape
# Out:
# (92663, 5)

# %%
coupon_item.isna().mean().round(4) *100 ### Checking percentage of NaN values in merged dataset
# Out:
# coupon_id     0.0
# item_id       0.0
# brand         0.0
# brand_type    0.0
# category      0.0
# dtype: float64

# %% [markdown]
# ### Combining all the merged datasets to put the customer transaction and other details together

# %%
cust_all_dtls= pd.merge(cust_tran_demograph,coupon_item, on='item_id', how='left')
cust_all_dtls.shape
# Out:
# (2657495, 19)

# %%
cust_all_dtls.isna().mean().round(4) *100 ### Checking percentage of NaN values in merged dataset
# Out:
# date                0.00
# customer_id         0.00
# item_id             0.00
# quantity            0.00
# selling_price       0.00
# other_discount      0.00
# coupon_discount     0.00
# marital_status     40.01
# rented             40.01
# family_size        40.01
# no_of_children     40.01
# income_bracket     40.01
# age_min            40.01
# age_max            40.01
# age_avg            40.01
# coupon_id          20.93
# brand              20.93
# brand_type         20.93
# category           20.93
# dtype: float64

# %%
train.isna().mean().round(4) * 100
# Out:
# id                   0.0
# campaign_id          0.0
# coupon_id            0.0
# customer_id          0.0
# redemption_status    0.0
# campaign_type        0.0
# start_date           0.0
# end_date             0.0
# dtype: float64

# %%
cust_all_dtls
# Out:
#                date  customer_id  item_id  quantity  selling_price  \
# 0        2012-01-02         1501    26830         1          35.26
# 1        2012-01-02         1501    26830         1          35.26
# 2        2012-01-02         1501    26830         1          35.26
# 3        2012-01-02         1501    54253         1          53.43
# 4        2012-01-02         1501    54253         1          53.43
# 5        2012-01-02         1501    54253         1          53.43
# 6        2012-01-02         1501    31962         1         106.50
# 7        2012-01-02         1501    33647         1          67.32
# 8        2012-01-02         1501    48199         1          71.24
# 9        2012-01-02         1501    48199         1          71.24
# 10       2012-01-02         1501    57397         1          71.24
# 11       2012-01-02         1501    57397         1          71.24
# 12       2012-01-02          857    12424         1         106.50
# 13       2012-01-02          857    14930         1         110.07
# 14       2012-01-02          857    14930         1         110.07
# 15       2012-01-02          857    14930         1         110.07
# 16       2012-01-02          857    16657         1          89.05
# 17       2012-01-02          857    16657         1          89.05
# 18       2012-01-02          857    16657         1          89.05
# 19       2012-01-02           67    10537         3          32.06
# 20       2012-01-02           67    19560         2         106.86
# 21       2012-01-02           67    21653         1          44.52
# 22       2012-01-02           67    32083         1           8.90
# 23       2012-01-02          751    10423         1          81.57
# 24       2012-01-02          751    10423         1          81.57
# 25       2012-01-02          751    10423         1          81.57
# 26       2012-01-02          751    10423         1          81.57
# 27       2012-01-02          751    10565         1          71.24
# 28       2012-01-02          751    10565         1          71.24
# 29       2012-01-02          751    10565         1          71.24
# ...             ...          ...      ...       ...            ...
# 2657465  2013-06-30         1129      769         1         184.87
# 2657466  2013-06-30         1129      769         1         184.87
# 2657467  2013-06-30         1129      769         1         184.87
# 2657468  2013-06-30         1129      861         1          74.45
# 2657469  2013-06-30         1129      936         1          45.95
# 2657470  2013-06-30         1129     1531         1         106.86
# 2657471  2013-06-30         1129     1536         2         178.10
# 2657472  2013-06-30         1129     1536         2         178.10
# 2657473  2013-06-30         1129     1536         2         178.10
# 2657474  2013-06-30         1129     1536         2         178.10
# 2657475  2013-06-30         1129     1536         2         178.10
# 2657476  2013-06-30         1129     1736         1          95.82
# 2657477  2013-06-30         1129     1736         1          95.82
# 2657478  2013-06-30         1129     2135         1          35.62
# 2657479  2013-06-30         1129     2142         1         146.04
# 2657480  2013-06-30         1129     2142         1         146.04
# 2657481  2013-06-30         1129     2142         1         146.04
# 2657482  2013-06-30         1129     2423         1          81.57
# 2657483  2013-06-30         1129     2423         1          81.57
# 2657484  2013-06-30         1129     2423         1          81.57
# 2657485  2013-06-30         1129     2423         1          81.57
# 2657486  2013-06-30         1129     2777         1         284.60
# 2657487  2013-06-30         1129     2777         1         284.60
# 2657488  2013-06-30         1129     2777         1         284.60
# 2657489  2013-06-30         1129     2953         4          42.74
# 2657490  2013-06-30         1129     2971         6          64.12
# 2657491  2013-06-30         1129    46984         1          95.82
# 2657492  2013-06-30         1129    64498         2         489.78
# 2657493  2013-06-30         1129    64498         2         489.78
# 2657494  2013-06-30         1129    64498         2         489.78
#
#          other_discount  coupon_discount  marital_status  rented family_size  \
# 0                -10.69              0.0             NaN     NaN         NaN
# 1                -10.69              0.0             NaN     NaN         NaN
# 2                -10.69              0.0             NaN     NaN         NaN
# 3                -13.89              0.0             NaN     NaN         NaN
# 4                -13.89              0.0             NaN     NaN         NaN
# 5                -13.89              0.0             NaN     NaN         NaN
# 6                -14.25              0.0             NaN     NaN         NaN
# 7                  0.00              0.0             NaN     NaN         NaN
# 8                -28.14              0.0             NaN     NaN         NaN
# 9                -28.14              0.0             NaN     NaN         NaN
# 10               -28.14              0.0             NaN     NaN         NaN
# 11               -28.14              0.0             NaN     NaN         NaN
# 12               -14.25              0.0             1.0     0.0           1
# 13                 0.00              0.0             1.0     0.0           1
# 14                 0.00              0.0             1.0     0.0           1
# 15                 0.00              0.0             1.0     0.0           1
# 16               -35.26              0.0             1.0     0.0           1
# 17               -35.26              0.0             1.0     0.0           1
# 18               -35.26              0.0             1.0     0.0           1
# 19                 0.00              0.0             1.0     0.0           2
# 20                -2.85              0.0             1.0     0.0           2
# 21               -12.11              0.0             1.0     0.0           2
# 22                 0.00              0.0             1.0     0.0           2
# 23                 0.00              0.0             1.0     0.0           1
# 24                 0.00              0.0             1.0     0.0           1
# 25                 0.00              0.0             1.0     0.0           1
# 26                 0.00              0.0             1.0     0.0           1
# 27               -35.26              0.0             1.0     0.0           1
# 28               -35.26              0.0             1.0     0.0           1
# 29               -35.26              0.0             1.0     0.0           1
# ...                 ...              ...             ...     ...         ...
# 2657465          -10.69              0.0             2.0     0.0           2
# 2657466          -10.69              0.0             2.0     0.0           2
# 2657467          -10.69              0.0             2.0     0.0           2
# 2657468            0.00              0.0             2.0     0.0           2
# 2657469           -4.63              0.0             2.0     0.0           2
# 2657470          -12.47              0.0             2.0     0.0           2
# 2657471         -106.15              0.0             2.0     0.0           2
# 2657472         -106.15              0.0             2.0     0.0           2
# 2657473         -106.15              0.0             2.0     0.0           2
# 2657474         -106.15              0.0             2.0     0.0           2
# 2657475         -106.15              0.0             2.0     0.0           2
# 2657476            0.00              0.0             2.0     0.0           2
# 2657477            0.00              0.0             2.0     0.0           2
# 2657478          -48.09              0.0             2.0     0.0           2
# 2657479         -117.90              0.0             2.0     0.0           2
# 2657480         -117.90              0.0             2.0     0.0           2
# 2657481         -117.90              0.0             2.0     0.0           2
# 2657482           -7.12              0.0             2.0     0.0           2
# 2657483           -7.12              0.0             2.0     0.0           2
# 2657484           -7.12              0.0             2.0     0.0           2
# 2657485           -7.12              0.0             2.0     0.0           2
# 2657486          -71.24              0.0             2.0     0.0           2
# 2657487          -71.24              0.0             2.0     0.0           2
# 2657488          -71.24              0.0             2.0     0.0           2
# 2657489          -28.50              0.0             2.0     0.0           2
# 2657490          -42.74              0.0             2.0     0.0           2
# 2657491            0.00              0.0             2.0     0.0           2
# 2657492            0.00              0.0             2.0     0.0           2
# 2657493            0.00              0.0             2.0     0.0           2
# 2657494            0.00              0.0             2.0     0.0           2
#
#         no_of_children  income_bracket  age_min  age_max  age_avg  coupon_id  \
# 0                  NaN             NaN      NaN      NaN      NaN        7.0
# 1                  NaN             NaN      NaN      NaN      NaN       20.0
# 2                  NaN             NaN      NaN      NaN      NaN       29.0
# 3                  NaN             NaN      NaN      NaN      NaN        7.0
# 4                  NaN             NaN      NaN      NaN      NaN       20.0
# 5                  NaN             NaN      NaN      NaN      NaN       29.0
# 6                  NaN             NaN      NaN      NaN      NaN      625.0
# 7                  NaN             NaN      NaN      NaN      NaN        NaN
# 8                  NaN             NaN      NaN      NaN      NaN      625.0
# 9                  NaN             NaN      NaN      NaN      NaN      624.0
# 10                 NaN             NaN      NaN      NaN      NaN      625.0
# 11                 NaN             NaN      NaN      NaN      NaN      624.0
# 12                   0             7.0     70.0     70.0     70.0        NaN
# 13                   0             7.0     70.0     70.0     70.0       24.0
# 14                   0             7.0     70.0     70.0     70.0        8.0
# 15                   0             7.0     70.0     70.0     70.0       33.0
# 16                   0             7.0     70.0     70.0     70.0       24.0
# 17                   0             7.0     70.0     70.0     70.0        8.0
# 18                   0             7.0     70.0     70.0     70.0       33.0
# 19                   1             4.0     36.0     45.0     40.5        NaN
# 20                   1             4.0     36.0     45.0     40.5        NaN
# 21                   1             4.0     36.0     45.0     40.5        NaN
# 22                   1             4.0     36.0     45.0     40.5        NaN
# 23                   0             5.0     26.0     35.0     30.5     1094.0
# 24                   0             5.0     26.0     35.0     30.5       23.0
# 25                   0             5.0     26.0     35.0     30.5       34.0
# 26                   0             5.0     26.0     35.0     30.5       32.0
# 27                   0             5.0     26.0     35.0     30.5      938.0
# 28                   0             5.0     26.0     35.0     30.5       23.0
# 29                   0             5.0     26.0     35.0     30.5       32.0
# ...                ...             ...      ...      ...      ...        ...
# 2657465              0             9.0     70.0     70.0     70.0        6.0
# 2657466              0             9.0     70.0     70.0     70.0       22.0
# 2657467              0             9.0     70.0     70.0     70.0       31.0
# 2657468              0             9.0     70.0     70.0     70.0        NaN
# 2657469              0             9.0     70.0     70.0     70.0      366.0
# 2657470              0             9.0     70.0     70.0     70.0        NaN
# 2657471              0             9.0     70.0     70.0     70.0      811.0
# 2657472              0             9.0     70.0     70.0     70.0       24.0
# 2657473              0             9.0     70.0     70.0     70.0        8.0
# 2657474              0             9.0     70.0     70.0     70.0      812.0
# 2657475              0             9.0     70.0     70.0     70.0       33.0
# 2657476              0             9.0     70.0     70.0     70.0       43.0
# 2657477              0             9.0     70.0     70.0     70.0       42.0
# 2657478              0             9.0     70.0     70.0     70.0        NaN
# 2657479              0             9.0     70.0     70.0     70.0        8.0
# 2657480              0             9.0     70.0     70.0     70.0       24.0
# 2657481              0             9.0     70.0     70.0     70.0       33.0
# 2657482              0             9.0     70.0     70.0     70.0        9.0
# 2657483              0             9.0     70.0     70.0     70.0       21.0
# 2657484              0             9.0     70.0     70.0     70.0      211.0
# 2657485              0             9.0     70.0     70.0     70.0       30.0
# 2657486              0             9.0     70.0     70.0     70.0       43.0
# 2657487              0             9.0     70.0     70.0     70.0       42.0
# 2657488              0             9.0     70.0     70.0     70.0     1084.0
# 2657489              0             9.0     70.0     70.0     70.0        NaN
# 2657490              0             9.0     70.0     70.0     70.0        NaN
# 2657491              0             9.0     70.0     70.0     70.0      367.0
# 2657492              0             9.0     70.0     70.0     70.0        8.0
# 2657493              0             9.0     70.0     70.0     70.0       24.0
# 2657494              0             9.0     70.0     70.0     70.0       33.0
#
#           brand   brand_type          category
# 0          56.0        Local  Natural Products
# 1          56.0        Local  Natural Products
# 2          56.0        Local  Natural Products
# 3          56.0        Local  Natural Products
# 4          56.0        Local  Natural Products
# 5          56.0        Local  Natural Products
# 6         524.0  Established           Grocery
# 7           NaN          NaN               NaN
# 8         524.0  Established           Grocery
# 9         524.0  Established           Grocery
# 10        524.0  Established           Grocery
# 11        524.0  Established           Grocery
# 12          NaN          NaN               NaN
# 13       3235.0  Established              Meat
# 14       3235.0  Established              Meat
# 15       3235.0  Established              Meat
# 16       2011.0  Established     Packaged Meat
# 17       2011.0  Established     Packaged Meat
# 18       2011.0  Established     Packaged Meat
# 19          NaN          NaN               NaN
# 20          NaN          NaN               NaN
# 21          NaN          NaN               NaN
# 22          NaN          NaN               NaN
# 23       2088.0  Established    Pharmaceutical
# 24       2088.0  Established    Pharmaceutical
# 25       2088.0  Established    Pharmaceutical
# 26       2088.0  Established    Pharmaceutical
# 27       1162.0  Established    Pharmaceutical
# 28       1162.0  Established    Pharmaceutical
# 29       1162.0  Established    Pharmaceutical
# ...         ...          ...               ...
# 2657465    56.0        Local           Grocery
# 2657466    56.0        Local           Grocery
# 2657467    56.0        Local           Grocery
# 2657468     NaN          NaN               NaN
# 2657469    56.0        Local           Grocery
# 2657470     NaN          NaN               NaN
# 2657471   984.0  Established     Packaged Meat
# 2657472   984.0  Established     Packaged Meat
# 2657473   984.0  Established     Packaged Meat
# 2657474   984.0  Established     Packaged Meat
# 2657475   984.0  Established     Packaged Meat
# 2657476   522.0  Established           Grocery
# 2657477   522.0  Established           Grocery
# 2657478     NaN          NaN               NaN
# 2657479  3781.0  Established              Meat
# 2657480  3781.0  Established              Meat
# 2657481  3781.0  Established              Meat
# 2657482    56.0        Local           Grocery
# 2657483    56.0        Local           Grocery
# 2657484    56.0        Local           Grocery
# 2657485    56.0        Local           Grocery
# 2657486  2074.0  Established           Grocery
# 2657487  2074.0  Established           Grocery
# 2657488  2074.0  Established           Grocery
# 2657489     NaN          NaN               NaN
# 2657490     NaN          NaN               NaN
# 2657491    56.0        Local           Grocery
# 2657492  3514.0  Established              Meat
# 2657493  3514.0  Established              Meat
# 2657494  3514.0  Established              Meat
#
# [2657495 rows x 19 columns]

# %% [markdown]
# ### Replacing NaN values in combined dataset with appropriate method of replacement

# %%
cust_all_dtls.marital_status.fillna(cust_all_dtls.marital_status.median(),  inplace=True)
cust_all_dtls.rented.fillna(cust_all_dtls.rented.median(), inplace=True)
cust_all_dtls.family_size.fillna(cust_all_dtls.family_size.median(), inplace=True)
cust_all_dtls.no_of_children.fillna(cust_all_dtls.no_of_children.median(), inplace=True)
cust_all_dtls.income_bracket.fillna(cust_all_dtls.income_bracket.median(), inplace=True)
cust_all_dtls.coupon_id.fillna(cust_all_dtls.coupon_id.median(), inplace=True)
cust_all_dtls.brand.fillna(cust_all_dtls.brand.mean(), inplace=True)
cust_all_dtls.age_min.fillna(cust_all_dtls.age_min.mean(), inplace=True)
cust_all_dtls.age_max.fillna(cust_all_dtls.age_max.mean(), inplace=True)
cust_all_dtls.age_avg.fillna(cust_all_dtls.age_avg.mean(), inplace=True)
cust_all_dtls.brand_type.fillna(cust_all_dtls.brand_type.mode()[0],inplace=True)
cust_all_dtls.category.fillna(cust_all_dtls.category.mode()[0], inplace=True)

# %%
cust_all_dtls.isna().mean().round(4) *100
# Out:
# date               0.0
# customer_id        0.0
# item_id            0.0
# quantity           0.0
# selling_price      0.0
# other_discount     0.0
# coupon_discount    0.0
# marital_status     0.0
# rented             0.0
# family_size        0.0
# no_of_children     0.0
# income_bracket     0.0
# age_min            0.0
# age_max            0.0
# age_avg            0.0
# coupon_id          0.0
# brand              0.0
# brand_type         0.0
# category           0.0
# dtype: float64

# %% [markdown]
# ### Check if all the customer Ids are contained in train and test datasets that are available in customer details dataset

# %%
print(set(train.customer_id)-set(cust_all_dtls.customer_id))
print(set(test.customer_id)-set(cust_all_dtls.customer_id))
# Out:
# set()
# set()

# %%
cust_all_dtls.dtypes
# Out:
# date                object
# customer_id          int64
# item_id              int64
# quantity             int64
# selling_price      float64
# other_discount     float64
# coupon_discount    float64
# marital_status     float64
# rented             float64
# family_size         object
# no_of_children      object
# income_bracket     float64
# age_min            float64
# age_max            float64
# age_avg            float64
# coupon_id          float64
# brand              float64
# brand_type          object
# category            object
# dtype: object

# %%
print(cust_all_dtls.family_size.unique())
print(cust_all_dtls.no_of_children.unique())
cust_all_dtls.family_size=cust_all_dtls.family_size.astype(int)
cust_all_dtls.no_of_children=cust_all_dtls.no_of_children.astype(int)
# Out:
# [2.0 '1' '2' 5 '3' '4']
# [0.0 '1' '3' '2']

# %%
# %%time
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

le.fit(cust_all_dtls['brand_type'].astype(str))
cust_all_dtls['brand_type']=le.transform(cust_all_dtls['brand_type'].astype(str))

le.fit(cust_all_dtls['category'].astype(str))
cust_all_dtls['category']=le.transform(cust_all_dtls['category'].astype(str))
# Out:
# CPU times: user 7.96 s, sys: 43.7 ms, total: 8.01 s
# Wall time: 8 s

# %%
# %%time
from datetime import datetime
cust_all_dtls['date']=[datetime.strptime(cust_all_dtls.date[i],'%Y-%m-%d') for i in range(len(cust_all_dtls))]
# Out:
# CPU times: user 2min 11s, sys: 248 ms, total: 2min 12s
# Wall time: 2min 12s

# %%
def data_engineering(actual):
    new = pd.DataFrame()
    
    def f1(x):
        return np.mean(np.diff(np.abs(np.diff(x))))
    
    def f2(x):
        return np.mean(np.abs(np.diff(x)))
    
    for col in actual.columns:
        if col in ['date', 'customer_id', 'item_id', 'coupon_id']:
            continue
        new[col + '_mean'] = actual.groupby(['customer_id'])[col].mean()
        new[col + '_min'] = actual.groupby(['customer_id'])[col].min()
        new[col + '_max'] = actual.groupby(['customer_id'])[col].max()
        new[col + '_std'] = actual.groupby(['customer_id'])[col].std()
        
        # Change. 1st order.
        new[col + '_mean_abs_change'] = actual.groupby('customer_id')[col].apply(f2)
        
        # Change of Change. 2nd order.
        new[col + '_mean_change_of_abs_change'] = actual.groupby('customer_id')[col].apply(f1)
        
        new[col + '_abs_max'] = actual.groupby('customer_id')[col].apply(lambda x: np.max(np.abs(x)))
        new[col + '_abs_min'] = actual.groupby('customer_id')[col].apply(lambda x: np.min(np.abs(x)))
        
    for col in actual.columns:
        if col in ['date', 'item_id', 'coupon_id']:
            new[col + '_qtylo'] = actual.groupby(['customer_id'])[col].quantile(.05)
            new[col + '_qtyhi'] = actual.groupby(['customer_id'])[col].quantile(.95)
            new[col + '_qtymid'] = actual.groupby(['customer_id'])[col].quantile(.50)
            new[col + '_min'] = actual.groupby(['customer_id'])[col].min()
            new[col + '_max'] = actual.groupby(['customer_id'])[col].max()
            new[col + '_count'] = actual.groupby('customer_id')[col].count()
            new[col + '_unique'] = actual.groupby('customer_id')[col].nunique()
            new[col + '_count_to_unq'] = new[col + '_count'] / new[col + '_unique']
            
            
    return new

# %%
# %%time
cust_dtls_engg = data_engineering(cust_all_dtls)
# Out:
# CPU times: user 53.3 s, sys: 1.02 s, total: 54.3 s
# Wall time: 54.3 s

# %%
cust_dtls_engg.shape
# Out:
# (1582, 144)

# %%
train_df =pd.merge(train, cust_dtls_engg, on='customer_id', how='left')
test_df =pd.merge(test, cust_dtls_engg, on='customer_id', how='left')
train_df.shape,test_df.shape
# Out:
# ((78369, 152), (50226, 151))

# %%
train_df.dtypes
# Out:
# id                                                   int64
# campaign_id                                          int64
# coupon_id                                            int64
# customer_id                                          int64
# redemption_status                                    int64
# campaign_type                                       object
# start_date                                          object
# end_date                                            object
# quantity_mean                                      float64
# quantity_min                                         int64
# quantity_max                                         int64
# quantity_std                                       float64
# quantity_mean_abs_change                           float64
# quantity_mean_change_of_abs_change                 float64
# quantity_abs_max                                     int64
# quantity_abs_min                                     int64
# selling_price_mean                                 float64
# selling_price_min                                  float64
# selling_price_max                                  float64
# selling_price_std                                  float64
# selling_price_mean_abs_change                      float64
# selling_price_mean_change_of_abs_change            float64
# selling_price_abs_max                              float64
# selling_price_abs_min                              float64
# other_discount_mean                                float64
# other_discount_min                                 float64
# other_discount_max                                 float64
# other_discount_std                                 float64
# other_discount_mean_abs_change                     float64
# other_discount_mean_change_of_abs_change           float64
#                                                  ...
# category_max                                         int64
# category_std                                       float64
# category_mean_abs_change                           float64
# category_mean_change_of_abs_change                 float64
# category_abs_max                                     int64
# category_abs_min                                     int64
# date_qtylo                                  datetime64[ns]
# date_qtyhi                                  datetime64[ns]
# date_qtymid                                 datetime64[ns]
# date_min                                    datetime64[ns]
# date_max                                    datetime64[ns]
# date_count                                           int64
# date_unique                                          int64
# date_count_to_unq                                  float64
# item_id_qtylo                                      float64
# item_id_qtyhi                                      float64
# item_id_qtymid                                     float64
# item_id_min                                          int64
# item_id_max                                          int64
# item_id_count                                        int64
# item_id_unique                                       int64
# item_id_count_to_unq                               float64
# coupon_id_qtylo                                    float64
# coupon_id_qtyhi                                    float64
# coupon_id_qtymid                                   float64
# coupon_id_min                                      float64
# coupon_id_max                                      float64
# coupon_id_count                                      int64
# coupon_id_unique                                     int64
# coupon_id_count_to_unq                             float64
# Length: 152, dtype: object

# %%
# %%time
from datetime import datetime
train_df['start_date']=[datetime.strptime(train_df['start_date'][i],'%d/%m/%y') for i in range(len(train_df))]
train_df['end_date']=[datetime.strptime(train_df['end_date'][i],'%d/%m/%y') for i in range(len(train_df))]
test_df['start_date']=[datetime.strptime(test_df['start_date'][i],'%d/%m/%y') for i in range(len(test_df))]
test_df['end_date']=[datetime.strptime(test_df['end_date'][i],'%d/%m/%y') for i in range(len(test_df))]
# Out:
# CPU times: user 7.54 s, sys: 19.4 ms, total: 7.56 s
# Wall time: 7.56 s

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

le.fit(train_df['campaign_type'].astype(str))
train_df['campaign_type']=le.transform(train_df['campaign_type'].astype(str))

le.fit(test_df['campaign_type'].astype(str))
test_df['campaign_type']=le.transform(test_df['campaign_type'].astype(str))

# %%
# %%time
train_df['cmpg_strt_end']=[(train_df.start_date[i]-train_df.end_date[i]).days for i in range(len(train_df))]
test_df['cmpg_strt_end']=[(test_df.start_date[i]-test_df.end_date[i]).days for i in range(len(test_df))]

train_df['cmpg_strt_trn_qlo']=[(train_df.start_date[i]-train_df.date_qtylo[i]).days for i in range(len(train_df))]
test_df['cmpg_strt_trn_qlo']=[(test_df.start_date[i]-test_df.date_qtylo[i]).days for i in range(len(test_df))]

train_df['cmpg_strt_trn_qhi']=[(train_df.start_date[i]-train_df.date_qtyhi[i]).days for i in range(len(train_df))]
test_df['cmpg_strt_trn_qhi']=[(test_df.start_date[i]-test_df.date_qtyhi[i]).days for i in range(len(test_df))]

train_df['cmpg_strt_trn_qmid']=[(train_df.start_date[i]-train_df.date_qtymid[i]).days for i in range(len(train_df))]
test_df['cmpg_strt_trn_qmid']=[(test_df.start_date[i]-test_df.date_qtymid[i]).days for i in range(len(test_df))]

train_df['cmpg_strt_trn_qmax']=[(train_df.start_date[i]-train_df.date_max[i]).days for i in range(len(train_df))]
test_df['cmpg_strt_trn_qmax']=[(test_df.start_date[i]-test_df.date_max[i]).days for i in range(len(test_df))]

train_df['cmpg_strt_trn_qmin']=[(train_df.start_date[i]-train_df.date_min[i]).days for i in range(len(train_df))]
test_df['cmpg_strt_trn_qmin']=[(test_df.start_date[i]-test_df.date_min[i]).days for i in range(len(test_df))]

train_df['cmpg_trn_lo_mid']=[(train_df.date_qtylo[i]-train_df.date_qtymid[i]).days for i in range(len(train_df))]
test_df['cmpg_trn_lo_mid']=[(test_df.date_qtylo[i]-test_df.date_qtymid[i]).days for i in range(len(test_df))]

train_df['cmpg_trn_mid_hi']=[(train_df.date_qtymid[i]-train_df.date_qtyhi[i]).days for i in range(len(train_df))]
test_df['cmpg_trn_mid_hi']=[(test_df.date_qtymid[i]-test_df.date_qtyhi[i]).days for i in range(len(test_df))]

train_df['cmpg_trn_min_max']=[(train_df.date_min[i]-train_df.date_max[i]).days for i in range(len(train_df))]
test_df['cmpg_trn_min_max']=[(test_df.date_min[i]-test_df.date_max[i]).days for i in range(len(test_df))]
# Out:
# CPU times: user 1min 30s, sys: 307 ms, total: 1min 30s
# Wall time: 1min 31s

# %%
cols_to_remove=['start_date','end_date','date_qtylo','date_qtymid','date_qtyhi','date_max','date_min']
train_df.drop(cols_to_remove, axis=1, inplace=True)
test_df.drop(cols_to_remove, axis=1, inplace=True)
train_df.shape,test_df.shape
# Out:
# ((78369, 154), (50226, 153))

# %%
train_df.drop(['id','customer_id','campaign_id','coupon_id'], axis=1, inplace=True)
test_df.drop(['id','customer_id','campaign_id','coupon_id'], axis=1, inplace=True)
train_df.shape, test_df.shape
# Out:
# ((78369, 150), (50226, 149))

# %%
print('Checking high correlation between all feature in train dataset:')
feature_names=[i for i in train_df.columns if train_df[i].dtypes != 'object']
X = train_df[feature_names]
corr_matrix = X.corr().abs()
high_corr_var=np.where(corr_matrix>0.7)
corr_var=[(corr_matrix.columns[x],corr_matrix.columns[y]) for x,y in zip(*high_corr_var) if x!=y and x<y]
print('Variable with high correlation are :',corr_var)
# Out:
# Checking high correlation between all feature in train dataset:
# Variable with high correlation are : [('quantity_mean', 'quantity_std'), ('quantity_mean', 'quantity_mean_abs_change'), ('quantity_max', 'quantity_std'), ('quantity_max', 'quantity_abs_max'), ('quantity_std', 'quantity_mean_abs_change'), ('quantity_std', 'quantity_abs_max'), ('selling_price_mean', 'selling_price_std'), ('selling_price_mean', 'selling_price_mean_abs_change'), ('selling_price_min', 'selling_price_abs_min'), ('selling_price_max', 'selling_price_abs_max'), ('selling_price_std', 'selling_price_mean_abs_change'), ('other_discount_mean', 'other_discount_std'), ('other_discount_mean', 'other_discount_mean_abs_change'), ('other_discount_min', 'other_discount_std'), ('other_discount_min', 'other_discount_abs_max'), ('other_discount_std', 'other_discount_mean_abs_change'), ('other_discount_std', 'other_discount_abs_max'), ('coupon_discount_mean', 'coupon_discount_std'), ('coupon_discount_mean', 'coupon_discount_mean_abs_change'), ('coupon_discount_min', 'coupon_discount_std'), ('coupon_discount_min', 'coupon_discount_abs_max'), ('coupon_discount_std', 'coupon_discount_mean_abs_change'), ('coupon_discount_std', 'coupon_discount_abs_max'), ('marital_status_mean', 'marital_status_min'), ('marital_status_mean', 'marital_status_max'), ('marital_status_mean', 'marital_status_abs_max'), ('marital_status_mean', 'marital_status_abs_min'), ('marital_status_min', 'marital_status_max'), ('marital_status_min', 'marital_status_abs_max'), ('marital_status_min', 'marital_status_abs_min'), ('marital_status_max', 'marital_status_abs_max'), ('marital_status_max', 'marital_status_abs_min'), ('marital_status_abs_max', 'marital_status_abs_min'), ('rented_mean', 'rented_min'), ('rented_mean', 'rented_max'), ('rented_mean', 'rented_abs_max'), ('rented_mean', 'rented_abs_min'), ('rented_min', 'rented_max'), ('rented_min', 'rented_abs_max'), ('rented_min', 'rented_abs_min'), ('rented_max', 'rented_abs_max'), ('rented_max', 'rented_abs_min'), ('rented_abs_max', 'rented_abs_min'), ('family_size_mean', 'family_size_min'), ('family_size_mean', 'family_size_max'), ('family_size_mean', 'family_size_abs_max'), ('family_size_mean', 'family_size_abs_min'), ('family_size_mean', 'no_of_children_mean'), ('family_size_mean', 'no_of_children_min'), ('family_size_mean', 'no_of_children_max'), ('family_size_mean', 'no_of_children_abs_max'), ('family_size_mean', 'no_of_children_abs_min'), ('family_size_min', 'family_size_max'), ('family_size_min', 'family_size_abs_max'), ('family_size_min', 'family_size_abs_min'), ('family_size_min', 'no_of_children_mean'), ('family_size_min', 'no_of_children_min'), ('family_size_min', 'no_of_children_max'), ('family_size_min', 'no_of_children_abs_max'), ('family_size_min', 'no_of_children_abs_min'), ('family_size_max', 'family_size_abs_max'), ('family_size_max', 'family_size_abs_min'), ('family_size_max', 'no_of_children_mean'), ('family_size_max', 'no_of_children_min'), ('family_size_max', 'no_of_children_max'), ('family_size_max', 'no_of_children_abs_max'), ('family_size_max', 'no_of_children_abs_min'), ('family_size_abs_max', 'family_size_abs_min'), ('family_size_abs_max', 'no_of_children_mean'), ('family_size_abs_max', 'no_of_children_min'), ('family_size_abs_max', 'no_of_children_max'), ('family_size_abs_max', 'no_of_children_abs_max'), ('family_size_abs_max', 'no_of_children_abs_min'), ('family_size_abs_min', 'no_of_children_mean'), ('family_size_abs_min', 'no_of_children_min'), ('family_size_abs_min', 'no_of_children_max'), ('family_size_abs_min', 'no_of_children_abs_max'), ('family_size_abs_min', 'no_of_children_abs_min'), ('no_of_children_mean', 'no_of_children_min'), ('no_of_children_mean', 'no_of_children_max'), ('no_of_children_mean', 'no_of_children_abs_max'), ('no_of_children_mean', 'no_of_children_abs_min'), ('no_of_children_min', 'no_of_children_max'), ('no_of_children_min', 'no_of_children_abs_max'), ('no_of_children_min', 'no_of_children_abs_min'), ('no_of_children_max', 'no_of_children_abs_max'), ('no_of_child ...

# %%
def correlation(dataset, threshold):
    col_corr = set() # Set of all the names of deleted columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if (corr_matrix.iloc[i, j] >= threshold) and (corr_matrix.columns[j] not in col_corr):
                colname = corr_matrix.columns[i] # getting the name of column
                col_corr.add(colname)
                if colname in dataset.columns:
                    del dataset[colname] # deleting the column from the dataset

    return dataset

# %%
train_df_uncorr=correlation(train_df, 0.7)
test_df_uncorr=correlation(test_df, 0.7)
train_df_uncorr.shape,test_df_uncorr.shape
# Out:
# ((78369, 85), (50226, 87))

# %%
print(set(train_df_uncorr.columns)-set(test_df_uncorr))
print(set(test_df_uncorr)-set(train_df_uncorr.columns))
# Out:
# {'redemption_status'}
# {'cmpg_strt_trn_qmid', 'item_id_min', 'cmpg_strt_trn_qhi'}

# %%
#test_df_uncorr.drop(['cmpg_strt_trn_qmid','item_id_min'], axis=1, inplace=True)
#train_df_uncorr.shape,test_df_uncorr.shape

# %%
y_trn = train_df['redemption_status']
train_df.drop('redemption_status', axis=1, inplace=True)

# %%
feature_names=[i for i in train_df.columns if i!= 'redemption_status']
X_trn = train_df[feature_names]
#y_trn = train_df['redemption_status']
X_tst = test_df[feature_names]

from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X_trn, y_trn,stratify=y_trn, test_size=0.3,random_state=8)

X_train.shape,y_train.shape,X_valid.shape,y_valid.shape,X_tst.shape
# Out:
# ((54858, 84), (54858,), (23511, 84), (23511,), (50226, 84))

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=8,min_samples_leaf=2, min_samples_split=5, max_features='auto').fit(X_train, y_train)
print('Accuracy of Decision Tree classifier on training set: {:.2f}'
     .format(clf.score(X_train, y_train)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'
     .format(clf.score(X_valid, y_valid)))

from sklearn import metrics
fpr_tr, tpr_tr, thresholds_tr = metrics.roc_curve(y_train, clf.predict(X_train))
fpr_vl, tpr_vl, thresholds_vl = metrics.roc_curve(y_valid, clf.predict(X_valid))
print("AUC on training set:",metrics.auc(fpr_tr, tpr_tr))
print("AUC on validation set:",metrics.auc(fpr_vl, tpr_vl))
# Out:
# Accuracy of Decision Tree classifier on training set: 0.99
# Accuracy of Decision Tree classifier on test set: 0.99
# AUC on training set: 0.5
# AUC on validation set: 0.5

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200,random_state=8,max_features = "auto",
                            min_samples_leaf=3,min_samples_split=4, oob_score = True,n_jobs = -1)
rf.fit(X_train, y_train)
print('Accuracy of Random Forest classifier on training set: {:.2f}'
     .format(rf.score(X_train, y_train)))
print('Accuracy of Random Forest classifier on test set: {:.2f}'
     .format(rf.score(X_valid, y_valid)))

from sklearn import metrics
fpr_tr, tpr_tr, thresholds_tr = metrics.roc_curve(y_train, rf.predict(X_train))
fpr_vl, tpr_vl, thresholds_vl = metrics.roc_curve(y_valid, rf.predict(X_valid))
print("AUC on training set:",metrics.auc(fpr_tr, tpr_tr))
print("AUC on validation set:",metrics.auc(fpr_vl, tpr_vl))
# Out:
# Accuracy of Random Forest classifier on training set: 0.99
# Accuracy of Random Forest classifier on test set: 0.99
# AUC on training set: 0.5
# AUC on validation set: 0.5

# %%
feature_importances = pd.DataFrame(rf.feature_importances_,
                                   index = X_train.columns,
                                    columns=['importance']).sort_values('importance',ascending=False)
imp_feature=feature_importances[feature_importances['importance']>=0.002].T.columns
print(len(imp_feature))
feature_importances
# Out:
# 47
#                                           importance
# cmpg_strt_trn_qlo                           0.241555
# cmpg_strt_end                               0.178718
# coupon_discount_mean                        0.049198
# campaign_type                               0.048022
# coupon_discount_std                         0.033185
# date_count_to_unq                           0.024472
# date_count                                  0.021350
# item_id_count_to_unq                        0.017991
# coupon_discount_min                         0.014946
# item_id_qtyhi                               0.014662
# item_id_qtylo                               0.014387
# selling_price_min                           0.013721
# coupon_id_qtyhi                             0.013531
# cmpg_trn_min_max                            0.013531
# cmpg_trn_lo_mid                             0.013316
# other_discount_std                          0.012911
# date_unique                                 0.012886
# item_id_max                                 0.012599
# brand_mean_abs_change                       0.012478
# selling_price_mean                          0.012335
# brand_type_mean                             0.012322
# category_mean                               0.011805
# quantity_mean                               0.011680
# other_discount_mean                         0.011468
# quantity_max                                0.011436
# cmpg_trn_mid_hi                             0.011252
# selling_price_max                           0.010948
# item_id_qtymid                              0.010372
# selling_price_mean_change_of_abs_change     0.010315
# brand_mean                                  0.010074
# ...                                              ...
# brand_type_min                              0.000000
# quantity_abs_min                            0.000000
# age_avg_mean_abs_change                     0.000000
# age_avg_mean_change_of_abs_change           0.000000
# family_size_mean_change_of_abs_change       0.000000
# other_discount_max                          0.000000
# coupon_discount_max                         0.000000
# coupon_discount_abs_min                     0.000000
# marital_status_std                          0.000000
# marital_status_mean_abs_change              0.000000
# marital_status_mean_change_of_abs_change    0.000000
# rented_std                                  0.000000
# rented_mean_abs_change                      0.000000
# rented_mean_change_of_abs_change            0.000000
# family_size_std                             0.000000
# family_size_mean_abs_change                 0.000000
# no_of_children_std                          0.000000
# other_discount_abs_min                      0.000000
# no_of_children_mean_abs_change              0.000000
# no_of_children_mean_change_of_abs_change    0.000000
# income_bracket_std                          0.000000
# income_bracket_mean_abs_change              0.000000
# income_bracket_mean_change_of_abs_change    0.000000
# age_min_mean_abs_change                     0.000000
# age_min_mean_change_of_abs_change           0.000000
# age_max_std                                 0.000000
# age_max_mean_abs_change                     0.000000
# age_max_mean_change_of_abs_change           0.000000
# age_avg_std                                 0.000000
# age_min_std                                 0.000000
#
# [84 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pylab as pl

X_trn[imp_feature].hist(bins=30, figsize=(20,24),layout=(8,6))
pl.suptitle("Histogram for each numeric input variable for item dataset")
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
rfi = RandomForestClassifier(n_estimators=200,random_state=8,max_features = "auto",
                            min_samples_leaf=2,min_samples_split=5, oob_score = True,n_jobs = -1)
rfi.fit(X_train[imp_feature], y_train)
print('Accuracy of Random Forest classifier on training set: {:.2f}'
     .format(rfi.score(X_train[imp_feature], y_train)))
print('Accuracy of Random Forest classifier on test set: {:.2f}'
     .format(rfi.score(X_valid[imp_feature], y_valid)))

from sklearn import metrics
fpr_tr, tpr_tr, thresholds_tr = metrics.roc_curve(y_train, rfi.predict(X_train[imp_feature]))
fpr_vl, tpr_vl, thresholds_vl = metrics.roc_curve(y_valid, rfi.predict(X_valid[imp_feature]))
print("AUC on training set:",metrics.auc(fpr_tr, tpr_tr))
print("AUC on validation set:",metrics.auc(fpr_vl, tpr_vl))
# Out:
# Accuracy of Random Forest classifier on training set: 0.99
# Accuracy of Random Forest classifier on test set: 0.99
# AUC on training set: 0.5
# AUC on validation set: 0.5

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(leaf_size=30,n_jobs=-1,n_neighbors=5,weights='distance',
                           algorithm='auto',metric='minkowski',p=2)
#knn = KNeighborsClassifier(leaf_size=20,n_jobs=-1,n_neighbors=3,weights='uniform',algorithm='auto',
#                           metric='minkowski',p=2)
knn.fit(X_train[imp_feature], y_train)
print('Accuracy of K-NN classifier on training set: {:.2f}'
     .format(knn.score(X_train[imp_feature], y_train)))
print('Accuracy of K-NN classifier on test set: {:.2f}'
     .format(knn.score(X_valid[imp_feature], y_valid)))

from sklearn import metrics
fpr_tr, tpr_tr, thresholds_tr = metrics.roc_curve(y_train, knn.predict(X_train[imp_feature]))
fpr_vl, tpr_vl, thresholds_vl = metrics.roc_curve(y_valid, knn.predict(X_valid[imp_feature]))
print("AUC on training set:",metrics.auc(fpr_tr, tpr_tr))
print("AUC on validation set:",metrics.auc(fpr_vl, tpr_vl))
# Out:
# Accuracy of K-NN classifier on training set: 0.99
# Accuracy of K-NN classifier on test set: 0.99
# AUC on training set: 0.5153734755107606
# AUC on validation set: 0.515616802994267

# %%
from sklearn import svm
svm = svm.SVC(kernel='sigmoid', C=1, gamma=.001, random_state=7)
svm.fit(X_train[imp_feature], y_train)
print('Accuracy of SVM classifier on training set: {:.2f}'
     .format(svm.score(X_train[imp_feature], y_train)))
print('Accuracy of SVM classifier on test set: {:.2f}'
     .format(svm.score(X_valid[imp_feature], y_valid)))

from sklearn import metrics
fpr_tr, tpr_tr, thresholds_tr = metrics.roc_curve(y_train, svm.predict(X_train[imp_feature]))
fpr_vl, tpr_vl, thresholds_vl = metrics.roc_curve(y_valid, svm.predict(X_valid[imp_feature]))
print("AUC on training set:",metrics.auc(fpr_tr, tpr_tr))
print("AUC on validation set:",metrics.auc(fpr_vl, tpr_vl))
# Out:
# Accuracy of SVM classifier on training set: 0.99
# Accuracy of SVM classifier on test set: 0.99
# AUC on training set: 0.5
# AUC on validation set: 0.5

# %%
#### xgb non-scaled data
import xgboost as xgb

param = {'silent':1, 'objective':'binary:logistic', 'booster':'gbtree','eta':0.01,'min_child_weight':2,
         'max_depth':9, 'eval_metric':'auc','gamma':.001,'max_delta_step':0,'subsample':.5,
         'alpha': 0,'colsample_bytree':.5,'lambda': 1, 'seed':41}  
xgtrain = xgb.DMatrix(X_train[imp_feature], label = y_train)
xgcv = xgb.DMatrix(X_valid[imp_feature], label = y_valid)
xgtest = xgb.DMatrix(X_tst[imp_feature])

watchlist = [(xgcv, 'eval'), (xgtrain, 'train')]
num_round = 1000
bst = xgb.train(param, xgtrain, num_round, watchlist, early_stopping_rounds = 10)
# Out:
# /anaconda3/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [0]	eval-auc:0.736587	train-auc:0.706266
# Multiple eval metrics have been passed: 'train-auc' will be used for early stopping.
#
# Will train until train-auc hasn't improved in 10 rounds.
# [1]	eval-auc:0.753446	train-auc:0.715954
# [2]	eval-auc:0.764237	train-auc:0.732421
# [3]	eval-auc:0.774091	train-auc:0.743502
# [4]	eval-auc:0.800241	train-auc:0.765932
# [5]	eval-auc:0.799757	train-auc:0.765942
# [6]	eval-auc:0.798899	train-auc:0.770092
# [7]	eval-auc:0.800128	train-auc:0.770402
# [8]	eval-auc:0.799997	train-auc:0.769037
# [9]	eval-auc:0.801573	train-auc:0.772661
# [10]	eval-auc:0.802463	train-auc:0.773456
# [11]	eval-auc:0.829834	train-auc:0.793317
# [12]	eval-auc:0.836008	train-auc:0.793557
# [13]	eval-auc:0.849846	train-auc:0.813312
# [14]	eval-auc:0.849613	train-auc:0.813047
# [15]	eval-auc:0.852562	train-auc:0.815272
# [16]	eval-auc:0.854564	train-auc:0.826222
# [17]	eval-auc:0.859014	train-auc:0.827999
# [18]	eval-auc:0.858959	train-auc:0.827569
# [19]	eval-auc:0.858347	train-auc:0.827705
# [20]	eval-auc:0.861171	train-auc:0.829266
# [21]	eval-auc:0.861217	train-auc:0.834218
# [22]	eval-auc:0.860576	train-auc:0.834398
# [23]	eval-auc:0.861277	train-auc:0.835097
# [24]	eval-auc:0.861349	train-auc:0.836352
# [25]	eval-auc:0.861	train-auc:0.836077
# [26]	eval-auc:0.860527	train-auc:0.835464
# [27]	eval-auc:0.859813	train-auc:0.835765
# [28]	eval-auc:0.860382	train-auc:0.836537
# [29]	eval-auc:0.86104	train-auc:0.837033
# [30]	eval-auc:0.861228	train-auc:0.837341
# [31]	eval-auc:0.861056	train-auc:0.837159
# [32]	eval-auc:0.859983	train-auc:0.836064
# [33]	eval-auc:0.859393	train-auc:0.835372
# [34]	eval-auc:0.859058	train-auc:0.834904
# [35]	eval-auc:0.859151	train-auc:0.834832
# [36]	eval-auc:0.860968	train-auc:0.83688
# [37]	eval-auc:0.861935	train-auc:0.837867
# [38]	eval-auc:0.86273	train-auc:0.838832
# [39]	eval-auc:0.863193	train-auc:0.839206
# [40]	eval-auc:0.86325	train-auc:0.839422
# [41]	eval-auc:0.862813	train-auc:0.839584
# [42]	eval-auc:0.862596	train-auc:0.839379
# [43]	eval-auc:0.86229	train-auc:0.838976
# [44]	eval-auc:0.862859	train-auc:0.83994
# [45]	eval-auc:0.868176	train-auc:0.844252
# [46]	eval-auc:0.868152	train-auc:0.844085
# [47]	eval-auc:0.867778	train-auc:0.84424
# [48]	eval-auc:0.868068	train-auc:0.844679
# [49]	eval-auc:0.86771	train-auc:0.844568
# [50]	eval-auc:0.867581	train-auc:0.844544
# [51]	eval-auc:0.868022	train-auc:0.845052
# [52]	eval-auc:0.871896	train-auc:0.851726
# [53]	eval-auc:0.872281	train-auc:0.851955
# [54]	eval-auc:0.872097	train-auc:0.851621
# [55]	eval-auc:0.871631	train-auc:0.853177
# [56]	eval-auc:0.871762	train-auc:0.853091
# [57]	eval-auc:0.87206	train-auc:0.853679
# [58]	eval-auc:0.872083	train-auc:0.853824
# [59]	eval-auc:0.872657	train-auc:0.854171
# [60]	eval-auc:0.872951	train-auc:0.85444
# [61]	eval-auc:0.872905	train-auc:0.854394
# [62]	eval-auc:0.873017	train-auc:0.854466
# [63]	eval-auc:0.873319	train-auc:0.85529
# [64]	eval-auc:0.873508	train-auc:0.86055
# [65]	eval-auc:0.873926	train-auc:0.861656
# [66]	eval-auc:0.874563	train-auc:0.86199
# [67]	eval-auc:0.877982	train-auc:0.86385
# [68]	eval-auc:0.877576	train-auc:0.865745
# [69]	eval-auc:0.877348	train-auc:0.865948
# [70]	eval-auc:0.877344	train-auc:0.865599
# [71]	eval-auc:0.877983	train-auc:0.866344
# [72]	eval-auc:0.877616	train-auc:0.866288
# [73]	eval-auc:0.877945	train-auc:0.8666
# [74]	eval-auc:0.877712	train-auc:0.866357
# [75]	eval-auc:0.877711	train-auc:0.866308
# [76]	eval-auc:0.878014	train-auc:0.866452
# [77]	eval-auc:0.878113	train-auc:0.86724
# [78]	eval-auc:0.877908	train-auc:0.867815
# [79]	eval-auc:0.877948	train-auc:0.86832
# [80]	eval-auc:0.879884	train-auc:0.871021
# [81]	eval-auc:0.88109	train-auc:0.871552
# [82]	eval-auc:0.880878	train-auc:0.871709
# [83]	eval-auc:0.880903	train-auc:0.872975
# [84]	eval-auc:0.880763	train-auc:0.872783
# [85]	eval-auc:0.880576	train-auc:0.872606
# [86]	eval-auc:0.881073	train-auc:0.873915
# [87]	eval-auc:0.881278	train-auc:0.873932
# [88]	eval-auc:0.882122	train-auc:0.875389
# [89]	eval-auc:0.882727	train-auc:0.878088
# [90]	eval-auc:0.883485	train-auc:0.878966
# [91]	eval-auc:0.883692	train-auc:0.878617
# [92]	eval-auc:0.883416	train-auc:0.878853
# [93]	eval-auc:0.883191	train-auc:0.87865
# [94]	eval-auc:0.883604	train-auc:0.879614
# [95]	eval-auc:0.885201	train-auc:0.88236
# [96]	eval-auc:0.885125	train-auc:0.882243
# [97]	eval-auc:0.88611	train-auc:0.88433
# [98]	eval-auc:0.886275	train-auc:0.884371
# [99]	eval-auc:0.886591	train-auc:0.884262
# [100]	eval-auc:0.88649	train-auc:0.885166
# [101]	eval-auc:0.887109	train-auc:0.885638
# [102]	eval-auc:0.887515	train-auc:0.885973
# [103]	eval-auc:0.887719	train-auc:0.886157
# [104]	eval-auc:0.888227	train-auc:0.886525
# [105]	eval-auc:0.888605	train-auc:0.886724
# [106]	eval-auc:0.888997	train-auc:0.88921
# [107]	eval-auc:0.888841	train-auc:0.888914
# [108]	eval-auc:0.889418	train-auc:0.889401
# [109]	eval-auc:0.889657	train-auc:0.889852
# [110]	eval-auc:0.88969	train-auc:0.89005
# [111]	eval-auc:0.889579	train-auc:0.890247
# [112]	eval-auc:0.889911	train-auc:0.890631
# [113]	eval-auc:0.889821	train-auc:0.89099
# [114]	eval-auc:0.890775	train-auc:0.891803
# [115]	eval-auc:0.891181	train-auc:0.892344
# [116]	eval-auc:0.891803	train-auc:0.894418
# [117]	eval-auc:0.892155	train-auc:0.894616
# [118]	eval-auc:0.893161	train-auc:0.89585
# [119]	eval-auc:0.894231	train-auc:0.896232
# [120]	eval-auc:0.894327	train-auc:0.896133
# [121]	eval-auc:0.894452	train-auc:0.89632
# [122]	eval-auc:0.894837	train-auc:0.897451
# [123]	eval-auc:0.895412	train-auc:0.897734
# [124]	eval-auc:0.895602	train-auc:0.898776
# [125]	eval-auc:0.895467	train-auc:0.898826
# [126]	eval-auc:0.89542	train-auc:0.89904
# [127]	eval-auc:0.89638	train-auc:0.899858
# [128]	eval-auc:0.896535	train-auc:0.900027
# [129]	eval-auc:0.896677	train-auc:0.900088
# [130]	eval-auc:0.896688	train-auc:0.900257
# [131]	eval-auc:0.896516	train-auc:0.900547
# [132]	eval-auc:0.896529	train-auc:0.900459
# [133]	eval-auc:0.896724	train-auc:0.900672
# [134]	eval-auc:0.896781	train-auc:0.901397
# [135]	eval-auc:0.89694	train-auc:0.90161
# [136]	eval-auc:0.897329	train-auc:0.902232
# [137]	eval-auc:0.897506	train-auc:0.903434
# [138]	eval-auc:0.897701	train-auc:0.903577
# [139]	eval-auc:0.898019	train-auc:0.903939
# [140]	eval-auc:0.898316	train-auc:0.904258
# [141]	eval-auc:0.89852	train-auc:0.904608
# [142]	eval-auc:0.898821	train-auc:0.905894
# [143]	eval-auc:0.898699	train-auc:0.906106
# [144]	eval-auc:0.899359	train-auc:0.906617
# [145]	eval-auc:0.899289	train-auc:0.906512
# [146]	eval-auc:0.899641	train-auc:0.906587
# [147]	eval-auc:0.899737	train-auc:0.906959
# [148]	eval-auc:0.900148	train-auc:0.90822
# [149]	eval-auc:0.90118	train-auc:0.909133
# [150]	eval-auc:0.901179	train-auc:0.909913
# [151]	eval-auc:0.901061	train-auc:0.910341
# [152]	eval-auc:0.901642	train-auc:0.911796
# [153]	eval-auc:0.902866	train-auc:0.912612
# [154]	eval-auc:0.903327	train-auc:0.913579
# [155]	eval-auc:0.903579	train-auc:0.914497
# [156]	eval-auc:0.903583	train-auc:0.914696
# [157]	eval-auc:0.903822	train-auc:0.914836
# [158]	eval-auc:0.904631	train-auc:0.915812
# [159]	eval-auc:0.904823	train-auc:0.915812
# [160]	eval-auc:0.904736	train-auc:0.915899
# [161]	eval-auc:0.904971	train-auc:0.916353
# [162]	eval-auc:0.905072	train-auc:0.917018
# [163]	eval-auc:0.90509	train-auc:0.916958
# [164]	eval-auc:0.905112	train-auc:0.917127
# [165]	eval-auc:0.905173	train-auc:0.917779
# [166]	eval-auc:0.905249	train-auc:0.917942
# [167]	eval-auc:0.906215	train-auc:0.920491
# [168]	eval-auc:0.906257	train-auc:0.921095
# [169]	eval-auc:0.906229	train-auc:0.921219
# [170]	eval-auc:0.906441	train-auc:0.921598
# [171]	eval-auc:0.906529	train-auc:0.92164
# [172]	eval-auc:0.906569	train-auc:0.921736
# [173]	eval-auc:0.906393	train-auc:0.921854
# [174]	eval-auc:0.906705	train-auc:0.922397
# [175]	eval-auc:0.906873	train-auc:0.922605
# [176]	eval-auc:0.906901	train-auc:0.922895
# [177]	eval-auc:0.906984	train-auc:0.923618
# [178]	eval-auc:0.907018	train-auc:0.923655
# [179]	eval-auc:0.907103	train-auc:0.924038
# [180]	eval-auc:0.907273	train-auc:0.924309
# [181]	eval-auc:0.907451	train-auc:0.924443
# [182]	eval-auc:0.907183	train-auc:0.924709
# [183]	eval-auc:0.90757	train-auc:0.92503
# [184]	eval-auc:0.907836	train-auc:0.925608
# [185]	eval-auc:0.907744	train-auc:0.925755
# [186]	eval-auc:0.90766	train-auc:0.926011
# [187]	eval-auc:0.908051	train-auc:0.926655
# [188]	eval-auc:0.908237	train-auc:0.927085
# [189]	eval-auc:0.908601	train-auc:0.927524
# [190]	eval-auc:0.908416	train-auc:0.927527
# [191]	eval-auc:0.908675	train-auc:0.927589
# [192]	eval-auc:0.908603	train-auc:0.927847
# [193]	eval-auc:0.90876	train-auc:0.928136
# [194]	eval-auc:0.909001	train-auc:0.928221
# [195]	eval-auc:0.908866	train-auc:0.928586
# [196]	eval-auc:0.908932	train-auc:0.928631
# [197]	eval-auc:0.909225	train-auc:0.929197
# [198]	eval-auc:0.909246	train-auc:0.929235
# [199]	eval-auc:0.909644	train-auc:0.92951
# [200]	eval-auc:0.90976	train-auc:0.929538
# [201]	eval-auc:0.909889	train-auc:0.929777
# [202]	eval-auc:0.909878	train-auc:0.92995
# [203]	eval-auc:0.909938	train-auc:0.929988
# [204]	eval-auc:0.910149	train-auc:0.930183
# [205]	eval-auc:0.910337	train-auc:0.930403
# [206]	eval-auc:0.910441	train-auc:0.930548
# [207]	eval-auc:0.910619	train-auc:0.930582
# [208]	eval-auc:0.910906	train-auc:0.930896
# [209]	eval-auc:0.910865	train-auc:0.931085
# [210]	eval-auc:0.910927	train-auc:0.931207
# [211]	eval-auc:0.910896	train-auc:0.931403
# [212]	eval-auc:0.910891	train-auc:0.931541
# [213]	eval-auc:0.910738	train-auc:0.931583
# [214]	eval-auc:0.910929	train-auc:0.932143
# [215]	eval-auc:0.910528	train-auc:0.93216
# [216]	eval-auc:0.910487	train-auc:0.932227
# [217]	eval-auc:0.910574	train-auc:0.932225
# [218]	eval-auc:0.910524	train-auc:0.932316
# [219]	eval-auc:0.910626	train-auc:0.932591
# [220]	eval-auc:0.910713	train-auc:0.932797
# [221]	eval-auc:0.91067	train-auc:0.933085
# [222]	eval-auc:0.910699	train-auc:0.933449
# [223]	eval-auc:0.910874	train-auc:0.933558
# [224]	eval-auc:0.911165	train-auc:0.933609
# [225]	eval-auc:0.911486	train-auc:0.933733
# [226]	eval-auc:0.911417	train-auc:0.933847
# [227]	eval-auc:0.911364	train-auc:0.933871
# [228]	eval-auc:0.911457	train-auc:0.933988
# [229]	eval-auc:0.911766	train-auc:0.934483
# [230]	eval-auc:0.911996	train-auc:0.934553
# [231]	eval-auc:0.911988	train-auc:0.934718
# [232]	eval-auc:0.912143	train-auc:0.93493
# [233]	eval-auc:0.9121	train-auc:0.935524
# [234]	eval-auc:0.912185	train-auc:0.935604
# [235]	eval-auc:0.912584	train-auc:0.936204
# [236]	eval-auc:0.912534	train-auc:0.936172
# [237]	eval-auc:0.912491	train-auc:0.936179
# [238]	eval-auc:0.912462	train-auc:0.936373
# [239]	eval-auc:0.912824	train-auc:0.937081
# [240]	eval-auc:0.913005	train-auc:0.937438
# [241]	eval-auc:0.913122	train-auc:0.937517
# [242]	eval-auc:0.91305	train-auc:0.9379
# [243]	eval-auc:0.913152	train-auc:0.93788
# [244]	eval-auc:0.91336	train-auc:0.938586
# [245]	eval-auc:0.913286	train-auc:0.938687
# [246]	eval-auc:0.913309	train-auc:0.938842
# [247]	eval-auc:0.913234	train-auc:0.938846
# [248]	eval-auc:0.913078	train-auc:0.938776
# [249]	eval-auc:0.91321	train-auc:0.938883
# [250]	eval-auc:0.913351	train-auc:0.939176
# [251]	eval-auc:0.913509	train-auc:0.939518
# [252]	eval-auc:0.913437	train-auc:0.939657
# [253]	eval-auc:0.913352	train-auc:0.939682
# [254]	eval-auc:0.913226	train-auc:0.939851
# [255]	eval-auc:0.913166	train-auc:0.939745
# [256]	eval-auc:0.913262	train-auc:0.939856
# [257]	eval-auc:0.913427	train-auc:0.939849
# [258]	eval-auc:0.913557	train-auc:0.940006
# [259]	eval-auc:0.91364	train-auc:0.940201
# [260]	eval-auc:0.913568	train-auc:0.94033
# [261]	eval-auc:0.913566	train-auc:0.940483
# [262]	eval-auc:0.913689	train-auc:0.940619
# [263]	eval-auc:0.913742	train-auc:0.940945
# [264]	eval-auc:0.914102	train-auc:0.941152
# [265]	eval-auc:0.914269	train-auc:0.941099
# [266]	eval-auc:0.914418	train-auc:0.94125
# [267]	eval-auc:0.91477	train-auc:0.941411
# [268]	eval-auc:0.914776	train-auc:0.941539
# [269]	eval-auc:0.91465	train-auc:0.941683
# [270]	eval-auc:0.914829	train-auc:0.941788
# [271]	eval-auc:0.915168	train-auc:0.941997
# [272]	eval-auc:0.915235	train-auc:0.942058
# [273]	eval-auc:0.915379	train-auc:0.942309
# [274]	eval-auc:0.915288	train-auc:0.942448
# [275]	eval-auc:0.915411	train-auc:0.942724
# [276]	eval-auc:0.915394	train-auc:0.942773
# [277]	eval-auc:0.915561	train-auc:0.942977
# [278]	eval-auc:0.915593	train-auc:0.943057
# [279]	eval-auc:0.915655	train-auc:0.943389
# [280]	eval-auc:0.915635	train-auc:0.943565
# [281]	eval-auc:0.915558	train-auc:0.943697
# [282]	eval-auc:0.915598	train-auc:0.94394
# [283]	eval-auc:0.915517	train-auc:0.944176
# [284]	eval-auc:0.915661	train-auc:0.944202
# [285]	eval-auc:0.915818	train-auc:0.944373
# [286]	eval-auc:0.915724	train-auc:0.944548
# [287]	eval-auc:0.915801	train-auc:0.944817
# [288]	eval-auc:0.915757	train-auc:0.944987
# [289]	eval-auc:0.915759	train-auc:0.945122
# [290]	eval-auc:0.915637	train-auc:0.945244
# [291]	eval-auc:0.915744	train-auc:0.945347
# [292]	eval-auc:0.91577	train-auc:0.945497
# [293]	eval-auc:0.915851	train-auc:0.945669
# [294]	eval-auc:0.915912	train-auc:0.945654
# [295]	eval-auc:0.915823	train-auc:0.945678
# [296]	eval-auc:0.915767	train-auc:0.945651
# [297]	eval-auc:0.915798	train-auc:0.945718
# [298]	eval-auc:0.915756	train-auc:0.945771
# [299]	eval-auc:0.915716	train-auc:0.94584
# [300]	eval-auc:0.915747	train-auc:0.946032
# [301]	eval-auc:0.915802	train-auc:0.946077
# [302]	eval-auc:0.915757	train-auc:0.946155
# [303]	eval-auc:0.91569	train-auc:0.946349
# [304]	eval-auc:0.915725	train-auc:0.946439
# [305]	eval-auc:0.915777	train-auc:0.946703
# [306]	eval-auc:0.915851	train-auc:0.9469
# [307]	eval-auc:0.915648	train-auc:0.947093
# [308]	eval-auc:0.915548	train-auc:0.947273
# [309]	eval-auc:0.915575	train-auc:0.947396
# [310]	eval-auc:0.915342	train-auc:0.947494
# [311]	eval-auc:0.915353	train-auc:0.94759
# [312]	eval-auc:0.915465	train-auc:0.947789
# [313]	eval-auc:0.915318	train-auc:0.947976
# [314]	eval-auc:0.915331	train-auc:0.948059
# [315]	eval-auc:0.915501	train-auc:0.948233
# [316]	eval-auc:0.915451	train-auc:0.948344
# [317]	eval-auc:0.915895	train-auc:0.948654
# [318]	eval-auc:0.915958	train-auc:0.948797
# [319]	eval-auc:0.915872	train-auc:0.948934
# [320]	eval-auc:0.91575	train-auc:0.948896
# [321]	eval-auc:0.915829	train-auc:0.948867
# [322]	eval-auc:0.915864	train-auc:0.94899
# [323]	eval-auc:0.915838	train-auc:0.94918
# [324]	eval-auc:0.915773	train-auc:0.949241
# [325]	eval-auc:0.915813	train-auc:0.949319
# [326]	eval-auc:0.915798	train-auc:0.949365
# [327]	eval-auc:0.915945	train-auc:0.949473
# [328]	eval-auc:0.915754	train-auc:0.94946
# [329]	eval-auc:0.915805	train-auc:0.949519
# [330]	eval-auc:0.91576	train-auc:0.949586
# [331]	eval-auc:0.915843	train-auc:0.949649
# [332]	eval-auc:0.915905	train-auc:0.949706
# [333]	eval-auc:0.915866	train-auc:0.949791
# [334]	eval-auc:0.915927	train-auc:0.949815
# [335]	eval-auc:0.916136	train-auc:0.950078
# [336]	eval-auc:0.915919	train-auc:0.95021
# [337]	eval-auc:0.915865	train-auc:0.95016
# [338]	eval-auc:0.91588	train-auc:0.950307
# [339]	eval-auc:0.915907	train-auc:0.950423
# [340]	eval-auc:0.915957	train-auc:0.950558
# [341]	eval-auc:0.916014	train-auc:0.950733
# [342]	eval-auc:0.916045	train-auc:0.950938
# [343]	eval-auc:0.916056	train-auc:0.951002
# [344]	eval-auc:0.91585	train-auc:0.95098
# [345]	eval-auc:0.915899	train-auc:0.951076
# [346]	eval-auc:0.915895	train-auc:0.951178
# [347]	eval-auc:0.915902	train-auc:0.951241
# [348]	eval-auc:0.91586	train-auc:0.951242
# [349]	eval-auc:0.915918	train-auc:0.951287
# [350]	eval-auc:0.916137	train-auc:0.9514
# [351]	eval-auc:0.915988	train-auc:0.951423
# [352]	eval-auc:0.915917	train-auc:0.951609
# [353]	eval-auc:0.915837	train-auc:0.951739
# [354]	eval-auc:0.915769	train-auc:0.951734
# [355]	eval-auc:0.916018	train-auc:0.951779
# [356]	eval-auc:0.916119	train-auc:0.951816
# [357]	eval-auc:0.916124	train-auc:0.951868
# [358]	eval-auc:0.916031	train-auc:0.952005
# [359]	eval-auc:0.916044	train-auc:0.952006
# [360]	eval-auc:0.916327	train-auc:0.952149
# [361]	eval-auc:0.916304	train-auc:0.952162
# [362]	eval-auc:0.916505	train-auc:0.952246
# [363]	eval-auc:0.916474	train-auc:0.952317
# [364]	eval-auc:0.916352	train-auc:0.952296
# [365]	eval-auc:0.916461	train-auc:0.9525
# [366]	eval-auc:0.91647	train-auc:0.95259
# [367]	eval-auc:0.916472	train-auc:0.952596
# [368]	eval-auc:0.91648	train-auc:0.952662
# [369]	eval-auc:0.916433	train-auc:0.952733
# [370]	eval-auc:0.916455	train-auc:0.952713
# [371]	eval-auc:0.916414	train-auc:0.952796
# [372]	eval-auc:0.916336	train-auc:0.952755
# [373]	eval-auc:0.916354	train-auc:0.952822
# [374]	eval-auc:0.916319	train-auc:0.95289
# [375]	eval-auc:0.916305	train-auc:0.952903
# [376]	eval-auc:0.916385	train-auc:0.952977
# [377]	eval-auc:0.916328	train-auc:0.953014
# [378]	eval-auc:0.916477	train-auc:0.953022
# [379]	eval-auc:0.916409	train-auc:0.953077
# [380]	eval-auc:0.916507	train-auc:0.953177
# [381]	eval-auc:0.916447	train-auc:0.953208
# [382]	eval-auc:0.9163	train-auc:0.953303
# [383]	eval-auc:0.916163	train-auc:0.953406
# [384]	eval-auc:0.916305	train-auc:0.953471
# [385]	eval-auc:0.916284	train-auc:0.953581
# [386]	eval-auc:0.916377	train-auc:0.953556
# [387]	eval-auc:0.916402	train-auc:0.95356
# [388]	eval-auc:0.916385	train-auc:0.953578
# [389]	eval-auc:0.916454	train-auc:0.953734
# [390]	eval-auc:0.916381	train-auc:0.953818
# [391]	eval-auc:0.916486	train-auc:0.95405
# [392]	eval-auc:0.916491	train-auc:0.954097
# [393]	eval-auc:0.916457	train-auc:0.954098
# [394]	eval-auc:0.916442	train-auc:0.954127
# [395]	eval-auc:0.916486	train-auc:0.954341
# [396]	eval-auc:0.916316	train-auc:0.954416
# [397]	eval-auc:0.916409	train-auc:0.954467
# [398]	eval-auc:0.916579	train-auc:0.954632
# [399]	eval-auc:0.916491	train-auc:0.954702
# [400]	eval-auc:0.916437	train-auc:0.954739
# [401]	eval-auc:0.916461	train-auc:0.954782
# [402]	eval-auc:0.916447	train-auc:0.954739
# [403]	eval-auc:0.916546	train-auc:0.954805
# [404]	eval-auc:0.916473	train-auc:0.954809
# [405]	eval-auc:0.91645	train-auc:0.954875
# [406]	eval-auc:0.91643	train-auc:0.954977
# [407]	eval-auc:0.916458	train-auc:0.95504
# [408]	eval-auc:0.916431	train-auc:0.9551
# [409]	eval-auc:0.916351	train-auc:0.955174
# [410]	eval-auc:0.916261	train-auc:0.95524
# [411]	eval-auc:0.91621	train-auc:0.95527
# [412]	eval-auc:0.916188	train-auc:0.955406
# [413]	eval-auc:0.916192	train-auc:0.955393
# [414]	eval-auc:0.916126	train-auc:0.955384
# [415]	eval-auc:0.916186	train-auc:0.955392
# [416]	eval-auc:0.916435	train-auc:0.95545
# [417]	eval-auc:0.916599	train-auc:0.955479
# [418]	eval-auc:0.916647	train-auc:0.955633
# [419]	eval-auc:0.91671	train-auc:0.955722
# [420]	eval-auc:0.916836	train-auc:0.955774
# [421]	eval-auc:0.916926	train-auc:0.955778
# [422]	eval-auc:0.916895	train-auc:0.955744
# [423]	eval-auc:0.916776	train-auc:0.955777
# [424]	eval-auc:0.91687	train-auc:0.955898
# [425]	eval-auc:0.917068	train-auc:0.955953
# [426]	eval-auc:0.917149	train-auc:0.956016
# [427]	eval-auc:0.917089	train-auc:0.956034
# [428]	eval-auc:0.917122	train-auc:0.956081
# [429]	eval-auc:0.917126	train-auc:0.956103
# [430]	eval-auc:0.917234	train-auc:0.956226
# [431]	eval-auc:0.917339	train-auc:0.956367
# [432]	eval-auc:0.917353	train-auc:0.956347
# [433]	eval-auc:0.917624	train-auc:0.956383
# [434]	eval-auc:0.917775	train-auc:0.956493
# [435]	eval-auc:0.917717	train-auc:0.956609
# [436]	eval-auc:0.917861	train-auc:0.956718
# [437]	eval-auc:0.917872	train-auc:0.956801
# [438]	eval-auc:0.917982	train-auc:0.956859
# [439]	eval-auc:0.91804	train-auc:0.957028
# [440]	eval-auc:0.918045	train-auc:0.957178
# [441]	eval-auc:0.918154	train-auc:0.957205
# [442]	eval-auc:0.918191	train-auc:0.957301
# [443]	eval-auc:0.91828	train-auc:0.957384
# [444]	eval-auc:0.918225	train-auc:0.957359
# [445]	eval-auc:0.918312	train-auc:0.957407
# [446]	eval-auc:0.918294	train-auc:0.957513
# [447]	eval-auc:0.91821	train-auc:0.957582
# [448]	eval-auc:0.918154	train-auc:0.95765
# [449]	eval-auc:0.918135	train-auc:0.95765
# [450]	eval-auc:0.918102	train-auc:0.957714
# [451]	eval-auc:0.918064	train-auc:0.95771
# [452]	eval-auc:0.918137	train-auc:0.957756
# [453]	eval-auc:0.918185	train-auc:0.957786
# [454]	eval-auc:0.918253	train-auc:0.957798
# [455]	eval-auc:0.91834	train-auc:0.957885
# [456]	eval-auc:0.918377	train-auc:0.957974
# [457]	eval-auc:0.918301	train-auc:0.957986
# [458]	eval-auc:0.918145	train-auc:0.958124
# [459]	eval-auc:0.91806	train-auc:0.958133
# [460]	eval-auc:0.918097	train-auc:0.958131
# [461]	eval-auc:0.91799	train-auc:0.958172
# [462]	eval-auc:0.918025	train-auc:0.958249
# [463]	eval-auc:0.918108	train-auc:0.958273
# [464]	eval-auc:0.918232	train-auc:0.958292
# [465]	eval-auc:0.918202	train-auc:0.958325
# [466]	eval-auc:0.918321	train-auc:0.958334
# [467]	eval-auc:0.918343	train-auc:0.958353
# [468]	eval-auc:0.918399	train-auc:0.958396
# [469]	eval-auc:0.918335	train-auc:0.958426
# [470]	eval-auc:0.918277	train-auc:0.958417
# [471]	eval-auc:0.918292	train-auc:0.958524
# [472]	eval-auc:0.918332	train-auc:0.958595
# [473]	eval-auc:0.918279	train-auc:0.958579
# [474]	eval-auc:0.91828	train-auc:0.958606
# [475]	eval-auc:0.918215	train-auc:0.958578
# [476]	eval-auc:0.918261	train-auc:0.958634
# [477]	eval-auc:0.918297	train-auc:0.958723
# [478]	eval-auc:0.918313	train-auc:0.958778
# [479]	eval-auc:0.918191	train-auc:0.958811
# [480]	eval-auc:0.918248	train-auc:0.958856
# [481]	eval-auc:0.918233	train-auc:0.958935
# [482]	eval-auc:0.918303	train-auc:0.959015
# [483]	eval-auc:0.918403	train-auc:0.959027
# [484]	eval-auc:0.918325	train-auc:0.95902
# [485]	eval-auc:0.918361	train-auc:0.959065
# [486]	eval-auc:0.918287	train-auc:0.959095
# [487]	eval-auc:0.918372	train-auc:0.959114
# [488]	eval-auc:0.918387	train-auc:0.959133
# [489]	eval-auc:0.918366	train-auc:0.959144
# [490]	eval-auc:0.918379	train-auc:0.959184
# [491]	eval-auc:0.918429	train-auc:0.95928
# [492]	eval-auc:0.918528	train-auc:0.959274
# [493]	eval-auc:0.918548	train-auc:0.959326
# [494]	eval-auc:0.918446	train-auc:0.959349
# [495]	eval-auc:0.918519	train-auc:0.959434
# [496]	eval-auc:0.918524	train-auc:0.959517
# [497]	eval-auc:0.918556	train-auc:0.959514
# [498]	eval-auc:0.918493	train-auc:0.959557
# [499]	eval-auc:0.918462	train-auc:0.959606
# [500]	eval-auc:0.918376	train-auc:0.959619
# [501]	eval-auc:0.918451	train-auc:0.959646
# [502]	eval-auc:0.918442	train-auc:0.959703
# [503]	eval-auc:0.918312	train-auc:0.959734
# [504]	eval-auc:0.91829	train-auc:0.959776
# [505]	eval-auc:0.918376	train-auc:0.959846
# [506]	eval-auc:0.918391	train-auc:0.959833
# [507]	eval-auc:0.918438	train-auc:0.959877
# [508]	eval-auc:0.918444	train-auc:0.959944
# [509]	eval-auc:0.918442	train-auc:0.959998
# [510]	eval-auc:0.91842	train-auc:0.96005
# [511]	eval-auc:0.918337	train-auc:0.96006
# [512]	eval-auc:0.918343	train-auc:0.960082
# [513]	eval-auc:0.918352	train-auc:0.960135
# [514]	eval-auc:0.918378	train-auc:0.960174
# [515]	eval-auc:0.918375	train-auc:0.96019
# [516]	eval-auc:0.91832	train-auc:0.960253
# [517]	eval-auc:0.918331	train-auc:0.960255
# [518]	eval-auc:0.918294	train-auc:0.960301
# [519]	eval-auc:0.918322	train-auc:0.960324
# [520]	eval-auc:0.918316	train-auc:0.960402
# [521]	eval-auc:0.918365	train-auc:0.960373
# [522]	eval-auc:0.918394	train-auc:0.960364
# [523]	eval-auc:0.918403	train-auc:0.960426
# [524]	eval-auc:0.918332	train-auc:0.960446
# [525]	eval-auc:0.918328	train-auc:0.960482
# [526]	eval-auc:0.918197	train-auc:0.960477
# [527]	eval-auc:0.918212	train-auc:0.960497
# [528]	eval-auc:0.91815	train-auc:0.960543
# [529]	eval-auc:0.918082	train-auc:0.960554
# [530]	eval-auc:0.918093	train-auc:0.960537
# [531]	eval-auc:0.918147	train-auc:0.960529
# [532]	eval-auc:0.918195	train-auc:0.960548
# [533]	eval-auc:0.918152	train-auc:0.960576
# [534]	eval-auc:0.918124	train-auc:0.960584
# [535]	eval-auc:0.918103	train-auc:0.960559
# [536]	eval-auc:0.918112	train-auc:0.9606
# [537]	eval-auc:0.918059	train-auc:0.96066
# [538]	eval-auc:0.918008	train-auc:0.960698
# [539]	eval-auc:0.917889	train-auc:0.960704
# [540]	eval-auc:0.917966	train-auc:0.960724
# [541]	eval-auc:0.917946	train-auc:0.960716
# [542]	eval-auc:0.917904	train-auc:0.960734
# [543]	eval-auc:0.918062	train-auc:0.960798
# [544]	eval-auc:0.918025	train-auc:0.960891
# [545]	eval-auc:0.918012	train-auc:0.960871
# [546]	eval-auc:0.917969	train-auc:0.960868
# [547]	eval-auc:0.917988	train-auc:0.960888
# [548]	eval-auc:0.917934	train-auc:0.960911
# [549]	eval-auc:0.917889	train-auc:0.960937
# [550]	eval-auc:0.917958	train-auc:0.960952
# [551]	eval-auc:0.918118	train-auc:0.961023
# [552]	eval-auc:0.918185	train-auc:0.961079
# [553]	eval-auc:0.918173	train-auc:0.961072
# [554]	eval-auc:0.918149	train-auc:0.961139
# [555]	eval-auc:0.918171	train-auc:0.961173
# [556]	eval-auc:0.91816	train-auc:0.961222
# [557]	eval-auc:0.918194	train-auc:0.961254
# [558]	eval-auc:0.918146	train-auc:0.961323
# [559]	eval-auc:0.918271	train-auc:0.961377
# [560]	eval-auc:0.918146	train-auc:0.961341
# [561]	eval-auc:0.918182	train-auc:0.961337
# [562]	eval-auc:0.918232	train-auc:0.961343
# [563]	eval-auc:0.918197	train-auc:0.961376
# [564]	eval-auc:0.918229	train-auc:0.961369
# [565]	eval-auc:0.918265	train-auc:0.961414
# [566]	eval-auc:0.918259	train-auc:0.961461
# [567]	eval-auc:0.918288	train-auc:0.961528
# [568]	eval-auc:0.918146	train-auc:0.961561
# [569]	eval-auc:0.918121	train-auc:0.961557
# [570]	eval-auc:0.918262	train-auc:0.96162
# [571]	eval-auc:0.918199	train-auc:0.96169
# [572]	eval-auc:0.918163	train-auc:0.961686
# [573]	eval-auc:0.918029	train-auc:0.961703
# [574]	eval-auc:0.917972	train-auc:0.961717
# [575]	eval-auc:0.917981	train-auc:0.961717
# [576]	eval-auc:0.917918	train-auc:0.961755
# [577]	eval-auc:0.917951	train-auc:0.961752
# [578]	eval-auc:0.917949	train-auc:0.961785
# [579]	eval-auc:0.917868	train-auc:0.961802
# [580]	eval-auc:0.917877	train-auc:0.961843
# [581]	eval-auc:0.917754	train-auc:0.961907
# [582]	eval-auc:0.917699	train-auc:0.961914
# [583]	eval-auc:0.917755	train-auc:0.961898
# [584]	eval-auc:0.917758	train-auc:0.961904
# [585]	eval-auc:0.917747	train-auc:0.961901
# [586]	eval-auc:0.917756	train-auc:0.961953
# [587]	eval-auc:0.91772	train-auc:0.961977
# [588]	eval-auc:0.917692	train-auc:0.961991
# [589]	eval-auc:0.917726	train-auc:0.962039
# [590]	eval-auc:0.91767	train-auc:0.962035
# [591]	eval-auc:0.917693	train-auc:0.96204
# [592]	eval-auc:0.917737	train-auc:0.962057
# [593]	eval-auc:0.917801	train-auc:0.962121
# [594]	eval-auc:0.917725	train-auc:0.962136
# [595]	eval-auc:0.917851	train-auc:0.962199
# [596]	eval-auc:0.917918	train-auc:0.962218
# [597]	eval-auc:0.917902	train-auc:0.962305
# [598]	eval-auc:0.917823	train-auc:0.962288
# [599]	eval-auc:0.917812	train-auc:0.962272
# [600]	eval-auc:0.917786	train-auc:0.962286
# [601]	eval-auc:0.917842	train-auc:0.962283
# [602]	eval-auc:0.917852	train-auc:0.962278
# [603]	eval-auc:0.917857	train-auc:0.962321
# [604]	eval-auc:0.917876	train-auc:0.962366
# [605]	eval-auc:0.917848	train-auc:0.962363
# [606]	eval-auc:0.917815	train-auc:0.962381
# [607]	eval-auc:0.91793	train-auc:0.962414
# [608]	eval-auc:0.917949	train-auc:0.962449
# [609]	eval-auc:0.917855	train-auc:0.962448
# [610]	eval-auc:0.917758	train-auc:0.962443
# [611]	eval-auc:0.917715	train-auc:0.962445
# [612]	eval-auc:0.917685	train-auc:0.962453
# [613]	eval-auc:0.917731	train-auc:0.962484
# [614]	eval-auc:0.917764	train-auc:0.962491
# [615]	eval-auc:0.917733	train-auc:0.962557
# [616]	eval-auc:0.917795	train-auc:0.962576
# [617]	eval-auc:0.917834	train-auc:0.962589
# [618]	eval-auc:0.917828	train-auc:0.962632
# [619]	eval-auc:0.917897	train-auc:0.962646
# [620]	eval-auc:0.917902	train-auc:0.962656
# [621]	eval-auc:0.917834	train-auc:0.962675
# [622]	eval-auc:0.917845	train-auc:0.962671
# [623]	eval-auc:0.917782	train-auc:0.962694
# [624]	eval-auc:0.917876	train-auc:0.962744
# [625]	eval-auc:0.917868	train-auc:0.962731
# [626]	eval-auc:0.917814	train-auc:0.962749
# [627]	eval-auc:0.917845	train-auc:0.962727
# [628]	eval-auc:0.917747	train-auc:0.962736
# [629]	eval-auc:0.917768	train-auc:0.962758
# [630]	eval-auc:0.917726	train-auc:0.962765
# [631]	eval-auc:0.917779	train-auc:0.962789
# [632]	eval-auc:0.917769	train-auc:0.962822
# [633]	eval-auc:0.917769	train-auc:0.962853
# [634]	eval-auc:0.917776	train-auc:0.962865
# [635]	eval-auc:0.917839	train-auc:0.962871
# [636]	eval-auc:0.917848	train-auc:0.962855
# [637]	eval-auc:0.917827	train-auc:0.962853
# [638]	eval-auc:0.917854	train-auc:0.9629
# [639]	eval-auc:0.917921	train-auc:0.962937
# [640]	eval-auc:0.917959	train-auc:0.963004
# [641]	eval-auc:0.918015	train-auc:0.962987
# [642]	eval-auc:0.917915	train-auc:0.962986
# [643]	eval-auc:0.917966	train-auc:0.962987
# [644]	eval-auc:0.917949	train-auc:0.963006
# [645]	eval-auc:0.917954	train-auc:0.963033
# [646]	eval-auc:0.917949	train-auc:0.963061
# [647]	eval-auc:0.917868	train-auc:0.963108
# [648]	eval-auc:0.917859	train-auc:0.963097
# [649]	eval-auc:0.917946	train-auc:0.963143
# [650]	eval-auc:0.917942	train-auc:0.963152
# [651]	eval-auc:0.917933	train-auc:0.963195
# [652]	eval-auc:0.917945	train-auc:0.963261
# [653]	eval-auc:0.918029	train-auc:0.963282
# [654]	eval-auc:0.917973	train-auc:0.963288
# [655]	eval-auc:0.917932	train-auc:0.963282
# [656]	eval-auc:0.917938	train-auc:0.963341
# [657]	eval-auc:0.918	train-auc:0.963384
# [658]	eval-auc:0.918078	train-auc:0.9634
# [659]	eval-auc:0.918076	train-auc:0.963389
# [660]	eval-auc:0.918032	train-auc:0.963429
# [661]	eval-auc:0.918008	train-auc:0.963459
# [662]	eval-auc:0.918044	train-auc:0.963481
# [663]	eval-auc:0.918084	train-auc:0.9635
# [664]	eval-auc:0.918054	train-auc:0.963534
# [665]	eval-auc:0.918076	train-auc:0.963548
# [666]	eval-auc:0.917977	train-auc:0.963537
# [667]	eval-auc:0.91797	train-auc:0.963588
# [668]	eval-auc:0.917926	train-auc:0.963609
# [669]	eval-auc:0.917929	train-auc:0.96365
# [670]	eval-auc:0.917956	train-auc:0.96363
# [671]	eval-auc:0.917942	train-auc:0.963685
# [672]	eval-auc:0.917997	train-auc:0.963671
# [673]	eval-auc:0.917989	train-auc:0.963741
# [674]	eval-auc:0.91799	train-auc:0.963767
# [675]	eval-auc:0.917987	train-auc:0.963825
# [676]	eval-auc:0.917934	train-auc:0.963841
# [677]	eval-auc:0.917888	train-auc:0.963849
# [678]	eval-auc:0.917867	train-auc:0.96385
# [679]	eval-auc:0.917952	train-auc:0.96387
# [680]	eval-auc:0.917907	train-auc:0.96387
# [681]	eval-auc:0.917941	train-auc:0.963931
# [682]	eval-auc:0.917887	train-auc:0.963921
# [683]	eval-auc:0.917841	train-auc:0.96396
# [684]	eval-auc:0.917868	train-auc:0.963948
# [685]	eval-auc:0.917847	train-auc:0.963955
# [686]	eval-auc:0.917814	train-auc:0.963958
# [687]	eval-auc:0.917787	train-auc:0.963972
# [688]	eval-auc:0.917733	train-auc:0.963992
# [689]	eval-auc:0.917756	train-auc:0.964023
# [690]	eval-auc:0.917867	train-auc:0.964088
# [691]	eval-auc:0.91789	train-auc:0.964094
# [692]	eval-auc:0.917818	train-auc:0.964148
# [693]	eval-auc:0.917788	train-auc:0.964181
# [694]	eval-auc:0.91785	train-auc:0.964196
# [695]	eval-auc:0.917802	train-auc:0.964241
# [696]	eval-auc:0.917855	train-auc:0.964239
# [697]	eval-auc:0.917786	train-auc:0.964253
# [698]	eval-auc:0.917695	train-auc:0.964345
# [699]	eval-auc:0.917762	train-auc:0.964333
# [700]	eval-auc:0.917833	train-auc:0.964361
# [701]	eval-auc:0.917862	train-auc:0.964402
# [702]	eval-auc:0.917801	train-auc:0.96442
# [703]	eval-auc:0.917887	train-auc:0.964457
# [704]	eval-auc:0.917936	train-auc:0.964447
# [705]	eval-auc:0.917933	train-auc:0.964471
# [706]	eval-auc:0.91791	train-auc:0.964454
# [707]	eval-auc:0.917821	train-auc:0.964477
# [708]	eval-auc:0.917848	train-auc:0.964524
# [709]	eval-auc:0.917828	train-auc:0.964577
# [710]	eval-auc:0.917791	train-auc:0.964577
# [711]	eval-auc:0.91778	train-auc:0.964594
# [712]	eval-auc:0.917812	train-auc:0.964611
# [713]	eval-auc:0.917783	train-auc:0.964635
# [714]	eval-auc:0.917838	train-auc:0.96466
# [715]	eval-auc:0.917833	train-auc:0.964692
# [716]	eval-auc:0.917961	train-auc:0.964709
# [717]	eval-auc:0.917944	train-auc:0.964714
# [718]	eval-auc:0.917921	train-auc:0.964743
# [719]	eval-auc:0.917911	train-auc:0.964749
# [720]	eval-auc:0.917908	train-auc:0.964754
# [721]	eval-auc:0.917903	train-auc:0.964763
# [722]	eval-auc:0.917877	train-auc:0.964786
# [723]	eval-auc:0.917874	train-auc:0.964805
# [724]	eval-auc:0.917907	train-auc:0.964825
# [725]	eval-auc:0.917982	train-auc:0.964844
# [726]	eval-auc:0.917912	train-auc:0.964869
# [727]	eval-auc:0.917919	train-auc:0.964861
# [728]	eval-auc:0.917876	train-auc:0.964883
# [729]	eval-auc:0.917895	train-auc:0.9649
# [730]	eval-auc:0.917814	train-auc:0.964921
# [731]	eval-auc:0.917816	train-auc:0.964926
# [732]	eval-auc:0.917839	train-auc:0.964927
# [733]	eval-auc:0.917833	train-auc:0.964934
# [734]	eval-auc:0.91781	train-auc:0.964942
# [735]	eval-auc:0.917818	train-auc:0.964994
# [736]	eval-auc:0.917798	train-auc:0.965039
# [737]	eval-auc:0.917826	train-auc:0.965041
# [738]	eval-auc:0.917796	train-auc:0.965082
# [739]	eval-auc:0.917797	train-auc:0.965088
# [740]	eval-auc:0.917812	train-auc:0.965125
# [741]	eval-auc:0.917817	train-auc:0.965142
# [742]	eval-auc:0.91786	train-auc:0.965152
# [743]	eval-auc:0.917922	train-auc:0.965176
# [744]	eval-auc:0.91792	train-auc:0.965175
# [745]	eval-auc:0.917901	train-auc:0.965233
# [746]	eval-auc:0.917992	train-auc:0.965253
# [747]	eval-auc:0.9179	train-auc:0.96528
# [748]	eval-auc:0.91787	train-auc:0.965299
# [749]	eval-auc:0.917902	train-auc:0.965346
# [750]	eval-auc:0.917924	train-auc:0.965369
# [751]	eval-auc:0.917844	train-auc:0.965383
# [752]	eval-auc:0.917845	train-auc:0.965416
# [753]	eval-auc:0.917795	train-auc:0.965416
# [754]	eval-auc:0.917776	train-auc:0.96547
# [755]	eval-auc:0.917799	train-auc:0.965513
# [756]	eval-auc:0.917817	train-auc:0.965545
# [757]	eval-auc:0.917733	train-auc:0.965554
# [758]	eval-auc:0.917699	train-auc:0.965594
# [759]	eval-auc:0.917654	train-auc:0.965634
# [760]	eval-auc:0.917668	train-auc:0.965671
# [761]	eval-auc:0.91767	train-auc:0.965705
# [762]	eval-auc:0.917662	train-auc:0.965685
# [763]	eval-auc:0.917668	train-auc:0.965706
# [764]	eval-auc:0.91763	train-auc:0.965735
# [765]	eval-auc:0.917676	train-auc:0.965752
# [766]	eval-auc:0.917706	train-auc:0.96575
# [767]	eval-auc:0.917713	train-auc:0.965747
# [768]	eval-auc:0.917662	train-auc:0.965775
# [769]	eval-auc:0.917644	train-auc:0.965784
# [770]	eval-auc:0.917626	train-auc:0.965797
# [771]	eval-auc:0.917587	train-auc:0.965831
# [772]	eval-auc:0.917574	train-auc:0.965814
# [773]	eval-auc:0.917578	train-auc:0.965846
# [774]	eval-auc:0.917476	train-auc:0.965871
# [775]	eval-auc:0.917457	train-auc:0.965875
# [776]	eval-auc:0.917497	train-auc:0.965886
# [777]	eval-auc:0.917449	train-auc:0.965907
# [778]	eval-auc:0.917352	train-auc:0.965917
# [779]	eval-auc:0.917354	train-auc:0.965942
# [780]	eval-auc:0.91736	train-auc:0.965956
# [781]	eval-auc:0.917388	train-auc:0.965968
# [782]	eval-auc:0.917364	train-auc:0.965979
# [783]	eval-auc:0.917293	train-auc:0.965978
# [784]	eval-auc:0.917321	train-auc:0.965999
# [785]	eval-auc:0.917348	train-auc:0.966039
# [786]	eval-auc:0.917304	train-auc:0.966062
# [787]	eval-auc:0.917301	train-auc:0.96607
# [788]	eval-auc:0.917306	train-auc:0.966095
# [789]	eval-auc:0.91723	train-auc:0.966136
# [790]	eval-auc:0.91726	train-auc:0.966154
# [791]	eval-auc:0.91729	train-auc:0.966173
# [792]	eval-auc:0.917208	train-auc:0.966176
# [793]	eval-auc:0.91728	train-auc:0.966184
# [794]	eval-auc:0.917248	train-auc:0.966199
# [795]	eval-auc:0.917257	train-auc:0.966189
# [796]	eval-auc:0.917288	train-auc:0.966205
# [797]	eval-auc:0.917283	train-auc:0.966232
# [798]	eval-auc:0.917336	train-auc:0.966239
# [799]	eval-auc:0.917318	train-auc:0.966233
# [800]	eval-auc:0.917275	train-auc:0.966244
# [801]	eval-auc:0.917266	train-auc:0.966257
# [802]	eval-auc:0.917294	train-auc:0.966284
# [803]	eval-auc:0.917307	train-auc:0.966293
# [804]	eval-auc:0.917204	train-auc:0.966295
# [805]	eval-auc:0.917219	train-auc:0.966315
# [806]	eval-auc:0.917225	train-auc:0.966318
# [807]	eval-auc:0.917274	train-auc:0.966352
# [808]	eval-auc:0.917362	train-auc:0.966376
# [809]	eval-auc:0.917427	train-auc:0.966385
# [810]	eval-auc:0.917362	train-auc:0.966433
# [811]	eval-auc:0.917386	train-auc:0.966444
# [812]	eval-auc:0.917467	train-auc:0.966444
# [813]	eval-auc:0.917393	train-auc:0.966449
# [814]	eval-auc:0.917369	train-auc:0.96646
# [815]	eval-auc:0.917406	train-auc:0.966468
# [816]	eval-auc:0.917386	train-auc:0.966532
# [817]	eval-auc:0.917377	train-auc:0.96654
# [818]	eval-auc:0.917355	train-auc:0.966553
# [819]	eval-auc:0.917424	train-auc:0.966591
# [820]	eval-auc:0.917412	train-auc:0.966601
# [821]	eval-auc:0.917383	train-auc:0.966627
# [822]	eval-auc:0.917492	train-auc:0.966641
# [823]	eval-auc:0.91751	train-auc:0.966664
# [824]	eval-auc:0.917492	train-auc:0.966677
# [825]	eval-auc:0.917528	train-auc:0.966696
# [826]	eval-auc:0.91745	train-auc:0.966698
# [827]	eval-auc:0.917468	train-auc:0.966708
# [828]	eval-auc:0.917478	train-auc:0.966733
# [829]	eval-auc:0.917472	train-auc:0.966727
# [830]	eval-auc:0.917405	train-auc:0.966763
# [831]	eval-auc:0.917428	train-auc:0.966777
# [832]	eval-auc:0.917508	train-auc:0.966827
# [833]	eval-auc:0.917507	train-auc:0.966833
# [834]	eval-auc:0.917513	train-auc:0.966849
# [835]	eval-auc:0.917538	train-auc:0.966867
# [836]	eval-auc:0.91749	train-auc:0.966873
# [837]	eval-auc:0.917501	train-auc:0.966886
# [838]	eval-auc:0.917474	train-auc:0.966901
# [839]	eval-auc:0.917405	train-auc:0.966954
# [840]	eval-auc:0.917459	train-auc:0.966969
# [841]	eval-auc:0.917414	train-auc:0.966979
# [842]	eval-auc:0.91742	train-auc:0.967012
# [843]	eval-auc:0.917502	train-auc:0.967053
# [844]	eval-auc:0.917427	train-auc:0.967064
# [845]	eval-auc:0.917469	train-auc:0.967101
# [846]	eval-auc:0.917441	train-auc:0.967099
# [847]	eval-auc:0.917481	train-auc:0.967136
# [848]	eval-auc:0.917458	train-auc:0.967162
# [849]	eval-auc:0.917449	train-auc:0.967161
# [850]	eval-auc:0.91745	train-auc:0.967179
# [851]	eval-auc:0.917416	train-auc:0.967241
# [852]	eval-auc:0.917402	train-auc:0.967259
# [853]	eval-auc:0.917442	train-auc:0.967276
# [854]	eval-auc:0.917387	train-auc:0.967315
# [855]	eval-auc:0.917398	train-auc:0.967332
# [856]	eval-auc:0.91738	train-auc:0.96736
# [857]	eval-auc:0.917331	train-auc:0.967385
# [858]	eval-auc:0.917418	train-auc:0.96739
# [859]	eval-auc:0.917369	train-auc:0.967412
# [860]	eval-auc:0.917403	train-auc:0.967435
# [861]	eval-auc:0.917414	train-auc:0.967476
# [862]	eval-auc:0.917436	train-auc:0.967479
# [863]	eval-auc:0.917548	train-auc:0.967471
# [864]	eval-auc:0.917531	train-auc:0.967496
# [865]	eval-auc:0.917539	train-auc:0.967514
# [866]	eval-auc:0.917557	train-auc:0.967501
# [867]	eval-auc:0.917541	train-auc:0.967531
# [868]	eval-auc:0.917523	train-auc:0.967554
# [869]	eval-auc:0.917511	train-auc:0.967571
# [870]	eval-auc:0.917478	train-auc:0.967579
# [871]	eval-auc:0.91746	train-auc:0.967586
# [872]	eval-auc:0.917495	train-auc:0.967617
# [873]	eval-auc:0.917526	train-auc:0.967618
# [874]	eval-auc:0.917535	train-auc:0.967662
# [875]	eval-auc:0.917502	train-auc:0.967668
# [876]	eval-auc:0.917484	train-auc:0.967667
# [877]	eval-auc:0.917491	train-auc:0.967686
# [878]	eval-auc:0.917407	train-auc:0.967687
# [879]	eval-auc:0.917432	train-auc:0.967723
# [880]	eval-auc:0.917412	train-auc:0.967751
# [881]	eval-auc:0.917402	train-auc:0.967755
# [882]	eval-auc:0.917426	train-auc:0.967767
# [883]	eval-auc:0.917452	train-auc:0.967773
# [884]	eval-auc:0.9175	train-auc:0.967806
# [885]	eval-auc:0.917604	train-auc:0.967836
# [886]	eval-auc:0.917672	train-auc:0.967861
# [887]	eval-auc:0.917643	train-auc:0.967886
# [888]	eval-auc:0.917582	train-auc:0.967902
# [889]	eval-auc:0.917517	train-auc:0.96793
# [890]	eval-auc:0.917557	train-auc:0.967963
# [891]	eval-auc:0.91748	train-auc:0.967961
# [892]	eval-auc:0.917496	train-auc:0.967985
# [893]	eval-auc:0.917437	train-auc:0.968019
# [894]	eval-auc:0.9174	train-auc:0.968027
# [895]	eval-auc:0.917348	train-auc:0.968012
# [896]	eval-auc:0.917345	train-auc:0.968033
# [897]	eval-auc:0.91732	train-auc:0.968034
# [898]	eval-auc:0.917233	train-auc:0.96805
# [899]	eval-auc:0.917249	train-auc:0.968052
# [900]	eval-auc:0.917246	train-auc:0.968063
# [901]	eval-auc:0.917262	train-auc:0.968077
# [902]	eval-auc:0.917313	train-auc:0.968075
# [903]	eval-auc:0.917322	train-auc:0.968089
# [904]	eval-auc:0.917309	train-auc:0.968099
# [905]	eval-auc:0.917307	train-auc:0.968126
# [906]	eval-auc:0.917318	train-auc:0.968115
# [907]	eval-auc:0.917372	train-auc:0.968151
# [908]	eval-auc:0.917433	train-auc:0.968163
# [909]	eval-auc:0.917418	train-auc:0.96817
# [910]	eval-auc:0.917376	train-auc:0.968169
# [911]	eval-auc:0.917429	train-auc:0.968172
# [912]	eval-auc:0.917428	train-auc:0.96818
# [913]	eval-auc:0.917417	train-auc:0.968202
# [914]	eval-auc:0.917434	train-auc:0.968218
# [915]	eval-auc:0.917461	train-auc:0.968239
# [916]	eval-auc:0.917464	train-auc:0.968238
# [917]	eval-auc:0.917499	train-auc:0.968244
# [918]	eval-auc:0.917533	train-auc:0.968269
# [919]	eval-auc:0.917564	train-auc:0.968305
# [920]	eval-auc:0.917554	train-auc:0.968325
# [921]	eval-auc:0.917619	train-auc:0.968322
# [922]	eval-auc:0.917682	train-auc:0.96835
# [923]	eval-auc:0.917653	train-auc:0.968354
# [924]	eval-auc:0.917616	train-auc:0.968373
# [925]	eval-auc:0.917587	train-auc:0.968403
# [926]	eval-auc:0.917555	train-auc:0.96842
# [927]	eval-auc:0.917514	train-auc:0.968451
# [928]	eval-auc:0.917493	train-auc:0.968475
# [929]	eval-auc:0.917437	train-auc:0.968494
# [930]	eval-auc:0.917444	train-auc:0.96852
# [931]	eval-auc:0.917487	train-auc:0.968549
# [932]	eval-auc:0.917529	train-auc:0.968545
# [933]	eval-auc:0.917515	train-auc:0.968575
# [934]	eval-auc:0.917485	train-auc:0.968576
# [935]	eval-auc:0.917467	train-auc:0.968577
# [936]	eval-auc:0.917412	train-auc:0.968606
# [937]	eval-auc:0.917387	train-auc:0.968639
# [938]	eval-auc:0.917301	train-auc:0.968651
# [939]	eval-auc:0.917263	train-auc:0.968674
# [940]	eval-auc:0.91732	train-auc:0.968697
# [941]	eval-auc:0.917266	train-auc:0.968712
# [942]	eval-auc:0.917295	train-auc:0.968752
# [943]	eval-auc:0.917319	train-auc:0.968745
# [944]	eval-auc:0.917349	train-auc:0.968754
# [945]	eval-auc:0.917309	train-auc:0.968774
# [946]	eval-auc:0.917332	train-auc:0.968793
# [947]	eval-auc:0.917281	train-auc:0.968785
# [948]	eval-auc:0.917277	train-auc:0.968785
# [949]	eval-auc:0.917291	train-auc:0.968787
# [950]	eval-auc:0.91729	train-auc:0.968793
# [951]	eval-auc:0.917301	train-auc:0.968845
# [952]	eval-auc:0.917285	train-auc:0.968842
# [953]	eval-auc:0.917188	train-auc:0.96886
# [954]	eval-auc:0.917214	train-auc:0.968871
# [955]	eval-auc:0.917203	train-auc:0.96888
# [956]	eval-auc:0.917152	train-auc:0.968906
# [957]	eval-auc:0.917113	train-auc:0.968929
# [958]	eval-auc:0.917129	train-auc:0.968945
# [959]	eval-auc:0.917147	train-auc:0.968965
# [960]	eval-auc:0.91712	train-auc:0.968969
# [961]	eval-auc:0.917077	train-auc:0.968973
# [962]	eval-auc:0.917013	train-auc:0.968989
# [963]	eval-auc:0.917016	train-auc:0.968987
# [964]	eval-auc:0.916958	train-auc:0.968977
# [965]	eval-auc:0.916933	train-auc:0.968981
# [966]	eval-auc:0.916965	train-auc:0.969003
# [967]	eval-auc:0.916946	train-auc:0.96903
# [968]	eval-auc:0.916897	train-auc:0.969054
# [969]	eval-auc:0.9169	train-auc:0.969046
# [970]	eval-auc:0.916936	train-auc:0.969081
# [971]	eval-auc:0.916901	train-auc:0.969098
# [972]	eval-auc:0.916913	train-auc:0.969115
# [973]	eval-auc:0.916925	train-auc:0.969128
# [974]	eval-auc:0.916829	train-auc:0.969128
# [975]	eval-auc:0.916795	train-auc:0.969144
# [976]	eval-auc:0.916747	train-auc:0.969166
# [977]	eval-auc:0.916717	train-auc:0.969179
# [978]	eval-auc:0.916741	train-auc:0.969205
# [979]	eval-auc:0.916739	train-auc:0.969211
# [980]	eval-auc:0.916785	train-auc:0.969247
# [981]	eval-auc:0.916761	train-auc:0.969258
# [982]	eval-auc:0.916696	train-auc:0.969268
# [983]	eval-auc:0.91676	train-auc:0.969312
# [984]	eval-auc:0.916735	train-auc:0.969306
# [985]	eval-auc:0.916736	train-auc:0.969333
# [986]	eval-auc:0.916725	train-auc:0.969352
# [987]	eval-auc:0.916714	train-auc:0.969357
# [988]	eval-auc:0.916723	train-auc:0.969359
# [989]	eval-auc:0.916734	train-auc:0.969365
# [990]	eval-auc:0.916722	train-auc:0.969367
# [991]	eval-auc:0.916724	train-auc:0.969364
# [992]	eval-auc:0.916693	train-auc:0.969376
# [993]	eval-auc:0.916731	train-auc:0.969371
# [994]	eval-auc:0.916768	train-auc:0.969394
# [995]	eval-auc:0.91678	train-auc:0.969394
# [996]	eval-auc:0.916798	train-auc:0.969399
# [997]	eval-auc:0.916798	train-auc:0.969407
# [998]	eval-auc:0.916737	train-auc:0.969421
# [999]	eval-auc:0.916763	train-auc:0.969421

# %%
preds = bst.predict(xgtrain)
preds_tr =[1 if preds[i]>0.008485 else 0 for i in range(len(preds))]
#print(preds)
#print(y_train) 0.008288, 0.008485, 0.424061, 0.424066

preds = bst.predict(xgcv)
preds_cv =[1 if preds[i]>0.008485 else 0 for i in range(len(preds))]

df=pd.DataFrame(preds,y_valid)
df.groupby(df.index).mean()
# Out:
#                           0
# redemption_status
# 0                  0.008485
# 1                  0.081837

# %%
from sklearn import metrics
print('Accuracy of XGB classifier on training set: {:.2f}'
     .format(metrics.accuracy_score(preds_tr, y_train)))
print('Accuracy of XGB classifier on test set: {:.2f}'
     .format(metrics.accuracy_score(preds_cv, y_valid)))

fpr_tr, tpr_tr, thresholds_tr = metrics.roc_curve(y_train, preds_tr)
fpr_vl, tpr_vl, thresholds_vl = metrics.roc_curve(y_valid, preds_cv)
print("AUC on training set:",metrics.auc(fpr_tr, tpr_tr))
print("AUC on validation set:",metrics.auc(fpr_vl, tpr_vl))
# Out:
# Accuracy of XGB classifier on training set: 0.85
# Accuracy of XGB classifier on test set: 0.84
# AUC on training set: 0.9207962628637236
# AUC on validation set: 0.8561667360655314

# %%
### Scaling data
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
X_tst_scaled=StandardScaler().fit_transform(X_tst)
X_tst_scaled=pd.DataFrame(X_tst_scaled,columns=[X_tst.columns])
X_trn_scaled=StandardScaler().fit_transform(X_trn)
X_trn_scaled=pd.DataFrame(X_trn_scaled,columns=[X_trn.columns])
X_train_scaled, X_valid_scaled, y_train, y_valid = train_test_split(X_trn_scaled, y_trn, 
                                                                   stratify=y_trn, test_size=0.3,random_state=8)

(X_train_scaled.shape,y_train.shape),(X_valid_scaled.shape,y_valid.shape)
# Out:
# (((54858, 84), (54858,)), ((23511, 84), (23511,)))

# %%
from sklearn.ensemble import RandomForestClassifier
rfs = RandomForestClassifier(n_estimators=200,random_state=13,max_features = "auto",
                            min_samples_leaf=2,min_samples_split=4, oob_score = True,n_jobs = -1)
rfs.fit(X_train_scaled, y_train)
print('Accuracy of Random Forest classifier on training set: {:.2f}'
     .format(rfs.score(X_train_scaled, y_train)))
print('Accuracy of Random Forest classifier on test set: {:.2f}'
     .format(rfs.score(X_valid_scaled, y_valid)))

from sklearn import metrics
fpr_tr, tpr_tr, thresholds_tr = metrics.roc_curve(y_train, rfs.predict(X_train_scaled))
fpr_vl, tpr_vl, thresholds_vl = metrics.roc_curve(y_valid, rfs.predict(X_valid_scaled))
print("AUC on training set:",metrics.auc(fpr_tr, tpr_tr))
print("AUC on validation set:",metrics.auc(fpr_vl, tpr_vl))
# Out:
# Accuracy of Random Forest classifier on training set: 0.99
# Accuracy of Random Forest classifier on test set: 0.99
# AUC on training set: 0.5
# AUC on validation set: 0.5

# %%
feature_importances = pd.DataFrame(rf.feature_importances_,
                                   index = X_train_scaled.columns,
                                    columns=['importance']).sort_values('importance',ascending=False)
imp_feature=feature_importances[feature_importances['importance']>=0.002].T.columns
print(len(imp_feature))
feature_importances
# Out:
# 47
#                                           importance
# cmpg_strt_trn_qlo                           0.241555
# cmpg_strt_end                               0.178718
# coupon_discount_mean                        0.049198
# campaign_type                               0.048022
# coupon_discount_std                         0.033185
# date_count_to_unq                           0.024472
# date_count                                  0.021350
# item_id_count_to_unq                        0.017991
# coupon_discount_min                         0.014946
# item_id_qtyhi                               0.014662
# item_id_qtylo                               0.014387
# selling_price_min                           0.013721
# coupon_id_qtyhi                             0.013531
# cmpg_trn_min_max                            0.013531
# cmpg_trn_lo_mid                             0.013316
# other_discount_std                          0.012911
# date_unique                                 0.012886
# item_id_max                                 0.012599
# brand_mean_abs_change                       0.012478
# selling_price_mean                          0.012335
# brand_type_mean                             0.012322
# category_mean                               0.011805
# quantity_mean                               0.011680
# other_discount_mean                         0.011468
# quantity_max                                0.011436
# cmpg_trn_mid_hi                             0.011252
# selling_price_max                           0.010948
# item_id_qtymid                              0.010372
# selling_price_mean_change_of_abs_change     0.010315
# brand_mean                                  0.010074
# ...                                              ...
# brand_type_min                              0.000000
# quantity_abs_min                            0.000000
# age_avg_mean_abs_change                     0.000000
# age_avg_mean_change_of_abs_change           0.000000
# family_size_mean_change_of_abs_change       0.000000
# other_discount_max                          0.000000
# coupon_discount_max                         0.000000
# coupon_discount_abs_min                     0.000000
# marital_status_std                          0.000000
# marital_status_mean_abs_change              0.000000
# marital_status_mean_change_of_abs_change    0.000000
# rented_std                                  0.000000
# rented_mean_abs_change                      0.000000
# rented_mean_change_of_abs_change            0.000000
# family_size_std                             0.000000
# family_size_mean_abs_change                 0.000000
# no_of_children_std                          0.000000
# other_discount_abs_min                      0.000000
# no_of_children_mean_abs_change              0.000000
# no_of_children_mean_change_of_abs_change    0.000000
# income_bracket_std                          0.000000
# income_bracket_mean_abs_change              0.000000
# income_bracket_mean_change_of_abs_change    0.000000
# age_min_mean_abs_change                     0.000000
# age_min_mean_change_of_abs_change           0.000000
# age_max_std                                 0.000000
# age_max_mean_abs_change                     0.000000
# age_max_mean_change_of_abs_change           0.000000
# age_avg_std                                 0.000000
# age_min_std                                 0.000000
#
# [84 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
rfsi = RandomForestClassifier(n_estimators=200,random_state=13,max_features = "auto",
                            min_samples_leaf=2,min_samples_split=5, oob_score = True,n_jobs = -1)
rfsi.fit(X_train_scaled[imp_feature], y_train)
print('Accuracy of Random Forest classifier on training set: {:.2f}'
     .format(rfsi.score(X_train_scaled[imp_feature], y_train)))
print('Accuracy of Random Forest classifier on test set: {:.2f}'
     .format(rfsi.score(X_valid_scaled[imp_feature], y_valid)))

pred_rf_tr=rfsi.predict_proba(X_train_scaled[imp_feature])
pred_rf_tr=[np.argmax(pred_rf_tr[i]) for i in range(len(pred_rf_tr))]

pred_rf_vl=rfsi.predict_proba(X_valid_scaled[imp_feature])
pred_rf_vl=[np.argmax(pred_rf_vl[i]) for i in range(len(pred_rf_vl))]

from sklearn import metrics
fpr_tr, tpr_tr, thresholds_tr = metrics.roc_curve(y_train, pred_rf_tr)
fpr_vl, tpr_vl, thresholds_vl = metrics.roc_curve(y_valid, pred_rf_vl)

print("AUC on training set:",metrics.auc(fpr_tr, tpr_tr))
print("AUC on validation set:",metrics.auc(fpr_vl, tpr_vl))
# Out:
# Accuracy of Random Forest classifier on training set: 0.99
# Accuracy of Random Forest classifier on test set: 0.99
# AUC on training set: 0.5
# AUC on validation set: 0.5

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(leaf_size=30,n_jobs=-1,n_neighbors=3,weights='distance',
                           algorithm='auto',metric='minkowski',p=2)
#knn = KNeighborsClassifier(leaf_size=20,n_jobs=-1,n_neighbors=3,weights='uniform',algorithm='auto',
#                           metric='minkowski',p=3)
knn.fit(X_train_scaled[imp_feature], y_train)
print('Accuracy of K-NN classifier on training set: {:.2f}'
     .format(knn.score(X_train_scaled[imp_feature], y_train)))
print('Accuracy of K-NN classifier on test set: {:.2f}'
     .format(knn.score(X_valid_scaled[imp_feature], y_valid)))

from sklearn import metrics
fpr_tr, tpr_tr, thresholds_tr = metrics.roc_curve(y_train, knn.predict(X_train_scaled[imp_feature]))
fpr_vl, tpr_vl, thresholds_vl = metrics.roc_curve(y_valid, knn.predict(X_valid_scaled[imp_feature]))
print("AUC on training set:",metrics.auc(fpr_tr, tpr_tr))
print("AUC on validation set:",metrics.auc(fpr_vl, tpr_vl))
# Out:
# Accuracy of K-NN classifier on training set: 0.99
# Accuracy of K-NN classifier on test set: 0.99
# AUC on training set: 0.5304893518458388
# AUC on validation set: 0.5172773766758649

# %%
from sklearn import svm
svm = svm.SVC(kernel='rbf', C=10, gamma=.001, random_state=7)
svm.fit(X_train_scaled[imp_feature], y_train)
print('Accuracy of SVM classifier on training set: {:.2f}'
     .format(svm.score(X_train_scaled[imp_feature], y_train)))
print('Accuracy of SVM classifier on test set: {:.2f}'
     .format(svm.score(X_valid_scaled[imp_feature], y_valid)))

from sklearn import metrics
fpr_tr, tpr_tr, thresholds_tr = metrics.roc_curve(y_train, svm.predict(X_train_scaled[imp_feature]))
fpr_vl, tpr_vl, thresholds_vl = metrics.roc_curve(y_valid, svm.predict(X_valid_scaled[imp_feature]))
print("AUC on training set:",metrics.auc(fpr_tr, tpr_tr))
print("AUC on validation set:",metrics.auc(fpr_vl, tpr_vl))

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import f1_score
model = VotingClassifier(estimators=[('rf', rfsi), ('knn', knn), ('svm', svm)], voting='hard')
model.fit(X_train_scaled[imp_feature], y_train)

from sklearn import metrics
fpr_tr, tpr_tr, thresholds_tr = metrics.roc_curve(y_train, model.predict(X_train_scaled[imp_feature]))
fpr_vl, tpr_vl, thresholds_vl = metrics.roc_curve(y_valid, model.predict(X_valid_scaled[imp_feature]))
print("AUC on training set:",metrics.auc(fpr_tr, tpr_tr))
print("AUC on validation set:",metrics.auc(fpr_vl, tpr_vl))

# %%
import xgboost as xgb

param = {'silent':1, 'objective':'binary:logistic', 'booster':'gbtree','eta':0.01,'min_child_weight':2,
         'max_depth':9, 'eval_metric':'auc','gamma':.001,'max_delta_step':0,'subsample':.5,
         'alpha': 0,'colsample_bytree':.5, 'lambda': .1, 'seed':41}
xgtrain = xgb.DMatrix(X_train_scaled[imp_feature], label = y_train)
xgcv = xgb.DMatrix(X_valid_scaled[imp_feature], label = y_valid)
xgtest = xgb.DMatrix(X_tst_scaled[imp_feature])

watchlist = [(xgcv, 'eval'), (xgtrain, 'train')]
num_round = 1000
bst = xgb.train(param, xgtrain, num_round, watchlist, early_stopping_rounds = 10)
# Out:
# /anaconda3/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [0]	eval-auc:0.858034	train-auc:0.840171
# Multiple eval metrics have been passed: 'train-auc' will be used for early stopping.
#
# Will train until train-auc hasn't improved in 10 rounds.
# [1]	eval-auc:0.882354	train-auc:0.877797
# [2]	eval-auc:0.890864	train-auc:0.895172
# [3]	eval-auc:0.893635	train-auc:0.899285
# [4]	eval-auc:0.894076	train-auc:0.907918
# [5]	eval-auc:0.893948	train-auc:0.910205
# [6]	eval-auc:0.895624	train-auc:0.91584
# [7]	eval-auc:0.895986	train-auc:0.916467
# [8]	eval-auc:0.898578	train-auc:0.917256
# [9]	eval-auc:0.899287	train-auc:0.920741
# [10]	eval-auc:0.899823	train-auc:0.922347
# [11]	eval-auc:0.900723	train-auc:0.923275
# [12]	eval-auc:0.90225	train-auc:0.925059
# [13]	eval-auc:0.903419	train-auc:0.927505
# [14]	eval-auc:0.903513	train-auc:0.928565
# [15]	eval-auc:0.904065	train-auc:0.930763
# [16]	eval-auc:0.907783	train-auc:0.933356
# [17]	eval-auc:0.908071	train-auc:0.934406
# [18]	eval-auc:0.908274	train-auc:0.934281
# [19]	eval-auc:0.907492	train-auc:0.934747
# [20]	eval-auc:0.907419	train-auc:0.934667
# [21]	eval-auc:0.907841	train-auc:0.935911
# [22]	eval-auc:0.907419	train-auc:0.936022
# [23]	eval-auc:0.909079	train-auc:0.936701
# [24]	eval-auc:0.909009	train-auc:0.936718
# [25]	eval-auc:0.909188	train-auc:0.938101
# [26]	eval-auc:0.910048	train-auc:0.938516
# [27]	eval-auc:0.910039	train-auc:0.941046
# [28]	eval-auc:0.91007	train-auc:0.941054
# [29]	eval-auc:0.909641	train-auc:0.941362
# [30]	eval-auc:0.909629	train-auc:0.941564
# [31]	eval-auc:0.910594	train-auc:0.941169
# [32]	eval-auc:0.910477	train-auc:0.941523
# [33]	eval-auc:0.910056	train-auc:0.941546
# [34]	eval-auc:0.910652	train-auc:0.941935
# [35]	eval-auc:0.911331	train-auc:0.942201
# [36]	eval-auc:0.911227	train-auc:0.942567
# [37]	eval-auc:0.911242	train-auc:0.942515
# [38]	eval-auc:0.911831	train-auc:0.942831
# [39]	eval-auc:0.911312	train-auc:0.942634
# [40]	eval-auc:0.910938	train-auc:0.942413
# [41]	eval-auc:0.91112	train-auc:0.942644
# [42]	eval-auc:0.910662	train-auc:0.943284
# [43]	eval-auc:0.910774	train-auc:0.944048
# [44]	eval-auc:0.910329	train-auc:0.944237
# [45]	eval-auc:0.91101	train-auc:0.945221
# [46]	eval-auc:0.911509	train-auc:0.945771
# [47]	eval-auc:0.910851	train-auc:0.945724
# [48]	eval-auc:0.910795	train-auc:0.945784
# [49]	eval-auc:0.910509	train-auc:0.945978
# [50]	eval-auc:0.910381	train-auc:0.946257
# [51]	eval-auc:0.90986	train-auc:0.946574
# [52]	eval-auc:0.910672	train-auc:0.947094
# [53]	eval-auc:0.911048	train-auc:0.947874
# [54]	eval-auc:0.911208	train-auc:0.947886
# [55]	eval-auc:0.911017	train-auc:0.947881
# [56]	eval-auc:0.910985	train-auc:0.947886
# [57]	eval-auc:0.91099	train-auc:0.948158
# [58]	eval-auc:0.910971	train-auc:0.948278
# [59]	eval-auc:0.911015	train-auc:0.948213
# [60]	eval-auc:0.911031	train-auc:0.948329
# [61]	eval-auc:0.911459	train-auc:0.949002
# [62]	eval-auc:0.911489	train-auc:0.949427
# [63]	eval-auc:0.912074	train-auc:0.949437
# [64]	eval-auc:0.912388	train-auc:0.94948
# [65]	eval-auc:0.912421	train-auc:0.949637
# [66]	eval-auc:0.912683	train-auc:0.949651
# [67]	eval-auc:0.912793	train-auc:0.950485
# [68]	eval-auc:0.912421	train-auc:0.950514
# [69]	eval-auc:0.912558	train-auc:0.950765
# [70]	eval-auc:0.913551	train-auc:0.951465
# [71]	eval-auc:0.91337	train-auc:0.95191
# [72]	eval-auc:0.913656	train-auc:0.952348
# [73]	eval-auc:0.913604	train-auc:0.952386
# [74]	eval-auc:0.913454	train-auc:0.952401
# [75]	eval-auc:0.913239	train-auc:0.952476
# [76]	eval-auc:0.91336	train-auc:0.952695
# [77]	eval-auc:0.913233	train-auc:0.952675
# [78]	eval-auc:0.913267	train-auc:0.952938
# [79]	eval-auc:0.913534	train-auc:0.952993
# [80]	eval-auc:0.914053	train-auc:0.95332
# [81]	eval-auc:0.91402	train-auc:0.953358
# [82]	eval-auc:0.913997	train-auc:0.95312
# [83]	eval-auc:0.91379	train-auc:0.952989
# [84]	eval-auc:0.913465	train-auc:0.952759
# [85]	eval-auc:0.913521	train-auc:0.952807
# [86]	eval-auc:0.913514	train-auc:0.953128
# [87]	eval-auc:0.913301	train-auc:0.953084
# [88]	eval-auc:0.913222	train-auc:0.953166
# [89]	eval-auc:0.912986	train-auc:0.953153
# [90]	eval-auc:0.913651	train-auc:0.953267
# [91]	eval-auc:0.914319	train-auc:0.953255
# Stopping. Best iteration:
# [81]	eval-auc:0.91402	train-auc:0.953358

# %%
preds = bst.predict(xgtrain)
preds_tr =[1 if preds[i]>0.204211 else 0 for i in range(len(preds))]
#print(preds)
#print(y_train) 0.008288, 0.008485, 0.424061, 0.424066

preds = bst.predict(xgcv)
preds_cv =[1 if preds[i]>0.204211 else 0 for i in range(len(preds))]

df=pd.DataFrame(preds,y_valid)
df.groupby(df.index).mean()
# Out:
#                           0
# redemption_status
# 0                  0.204211
# 1                  0.236313

# %%
from sklearn import metrics
print('Accuracy of XGB classifier on training set: {:.2f}'
     .format(metrics.accuracy_score(preds_tr, y_train)))
print('Accuracy of XGB classifier on test set: {:.2f}'
     .format(metrics.accuracy_score(preds_cv, y_valid)))

fpr_tr, tpr_tr, thresholds_tr = metrics.roc_curve(y_train, preds_tr)
fpr_vl, tpr_vl, thresholds_vl = metrics.roc_curve(y_valid, preds_cv)
print("AUC on training set:",metrics.auc(fpr_tr, tpr_tr))
print("AUC on validation set:",metrics.auc(fpr_vl, tpr_vl))
# Out:
# Accuracy of XGB classifier on training set: 0.80
# Accuracy of XGB classifier on test set: 0.80
# AUC on training set: 0.8915275847587877
# AUC on validation set: 0.8397247923327195

# %%
pred_xgb=bst.predict(xgtest)
pred_xgb=[1 if pred_xgb[i]>0.008485 else 0 for i in range(len(pred_xgb))]

sub['redemption_status'] = pred_xgb
sub.to_csv('sub_AmEx_xgboost_tree.csv', index=False)
